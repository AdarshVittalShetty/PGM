# %% [markdown]
# ## Making Inferences in the ASIA graph

# %% [markdown]
# Notebook layout:
# 1. Load ASIA model
# 2. Make inferences

# %% [markdown]
# ## Graph
# ![ASIA Graph](ASIA.jpg)

# %% [markdown]
# ## 1. Load ASIA Model

# %%
# import essential libraries to manipulate data
import numpy as np
import pandas as pd

# import pgmpy functions
from pgmpy.readwrite import BIFReader
from pgmpy.inference import VariableElimination

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# load model
data = BIFReader('asia.bif')
asia_model = data.get_model()

# %%
# print nodes of the model
asia_model.nodes()
# Out:
# NodeView(('asia', 'tub', 'smoke', 'lung', 'bronc', 'either', 'xray', 'dysp'))

# %%
# print edges of the model
asia_model.edges()
# Out:
# OutEdgeView([('asia', 'tub'), ('tub', 'either'), ('smoke', 'lung'), ('smoke', 'bronc'), ('lung', 'either'), ('bronc', 'dysp'), ('either', 'xray'), ('either', 'dysp')])

# %%
# get model parameters
asia_model.get_cpds()
# Out:
# [<TabularCPD representing P(asia:2) at 0x24f7bcdd9e8>,
#  <TabularCPD representing P(bronc:2 | smoke:2) at 0x24f7bcddc18>,
#  <TabularCPD representing P(dysp:2 | bronc:2, either:2) at 0x24f7bcdddd8>,
#  <TabularCPD representing P(either:2 | lung:2, tub:2) at 0x24f7bcddc50>,
#  <TabularCPD representing P(lung:2 | smoke:2) at 0x24f7bcddc88>,
#  <TabularCPD representing P(smoke:2) at 0x24f7bcddcf8>,
#  <TabularCPD representing P(tub:2 | asia:2) at 0x24f7bcdd828>,
#  <TabularCPD representing P(xray:2 | either:2) at 0x24f7bcdd860>]

# %%
# print the CPDs by iterating through them
for cpd in asia_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    print(cpd.name_to_no)
# Out:
# CPD of asia:
# +-----------+------+
# | asia(yes) | 0.01 |
# +-----------+------+
# | asia(no)  | 0.99 |
# +-----------+------+
# {'asia': {'yes': 0, 'no': 1}}
# CPD of bronc:
# +------------+------------+-----------+
# | smoke      | smoke(yes) | smoke(no) |
# +------------+------------+-----------+
# | bronc(yes) | 0.6        | 0.3       |
# +------------+------------+-----------+
# | bronc(no)  | 0.4        | 0.7       |
# +------------+------------+-----------+
# {'smoke': {'yes': 0, 'no': 1}, 'bronc': {'yes': 0, 'no': 1}}
# CPD of dysp:
# +-----------+-------------+------------+-------------+------------+
# | bronc     | bronc(yes)  | bronc(yes) | bronc(no)   | bronc(no)  |
# +-----------+-------------+------------+-------------+------------+
# | either    | either(yes) | either(no) | either(yes) | either(no) |
# +-----------+-------------+------------+-------------+------------+
# | dysp(yes) | 0.9         | 0.8        | 0.7         | 0.1        |
# +-----------+-------------+------------+-------------+------------+
# | dysp(no)  | 0.1         | 0.2        | 0.3         | 0.9        |
# +-----------+-------------+------------+-------------+------------+
# {'bronc': {'yes': 0, 'no': 1}, 'either': {'yes': 0, 'no': 1}, 'dysp': {'yes': 0, 'no': 1}}
# CPD of either:
# +-------------+-----------+-----------+----------+----------+
# | lung        | lung(yes) | lung(yes) | lung(no) | lung(no) |
# +-------------+-----------+-----------+----------+----------+
# | tub         | tub(yes)  | tub(no)   | tub(yes) | tub(no)  |
# +-------------+-----------+-----------+----------+----------+
# | either(yes) | 1.0       | 1.0       | 1.0      | 0.0      |
# +-------------+-----------+-----------+----------+----------+
# | either(no)  | 0.0       | 0.0       | 0.0      | 1.0      |
# +-------------+-----------+-----------+----------+----------+
# {'lung': {'yes': 0, 'no': 1}, 'tub': {'yes': 0, 'no': 1}, 'either': {'yes': 0, 'no': 1}}
# CPD of lung:
# +-----------+------------+-----------+
# | smoke     | smoke(yes) | smoke(no) |
# +-----------+------------+-----------+
# | lung(yes) | 0.1        | 0.01      |
# +-----------+------------+-----------+
# | lung(no)  | 0.9        | 0.99      |
# +-----------+------------+-----------+
# {'smoke': {'yes': 0, 'no': 1}, 'lung': {'yes': 0, 'no': 1}}
# CPD of smoke:
# +------------+-----+
# | smoke(yes) | 0.5 |
# +------------+-----+
# | smoke(no)  | 0.5 |
# +------------+-----+
# {'smoke': {'yes': 0, 'no': 1}}
# CPD of tub:
# +----------+-----------+----------+
# | asia     | asia(yes) | asia(no) |
# +----------+-----------+----------+
# | tub(yes) | 0.05      | 0.01     |
# +----------+-----------+----------+
# | tub(no)  | 0.95      | 0.99     |
# +----------+-----------+----------+
# {'asia': {'yes': 0, 'no': 1}, 'tub': {'yes': 0, 'no': 1}}
# CPD of xray:
# +-----------+-------------+------------+
# | either    | either(yes) | either(no) |
# +-----------+-------------+------------+
# | xray(yes) | 0.98        | 0.05       |
# +-----------+-------------+------------+
# | xray(no)  | 0.02        | 0.95       |
# +-----------+-------------+------------+
# {'either': {'yes': 0, 'no': 1}, 'xray': {'yes': 0, 'no': 1}}

# %% [markdown]
# #### NOTE : Here the 'yes' denotes 0 and 'no' denotes 1. Because of the recent updates in pgmpy, the way it stores the variables changed too.

# %%
# get independencies
asia_model.get_independencies()
# Out:
# (asia _|_ smoke, lung, bronc)
# (asia _|_ smoke, lung | bronc)
# (asia _|_ either, smoke, lung, xray, dysp, bronc | tub)
# (asia _|_ xray | either)
# (asia _|_ lung, bronc | smoke)
# (asia _|_ smoke, bronc | lung)
# (asia _|_ either, smoke, lung, xray, dysp | tub, bronc)
# (asia _|_ dysp, xray | either, bronc)
# (asia _|_ lung | smoke, bronc)
# (asia _|_ smoke | lung, bronc)
# (asia _|_ smoke, lung, xray, dysp, bronc | either, tub)
# (asia _|_ either, lung, xray, dysp, bronc | smoke, tub)
# (asia _|_ either, smoke, xray, dysp, bronc | lung, tub)
# (asia _|_ either, smoke, lung, dysp, bronc | xray, tub)
# (asia _|_ either, smoke, lung, xray, bronc | dysp, tub)
# (asia _|_ dysp, xray, bronc | either, smoke)
# (asia _|_ dysp, smoke, xray, bronc | either, lung)
# (asia _|_ xray | dysp, either)
# (asia _|_ bronc | smoke, lung)
# (asia _|_ bronc | smoke, xray)
# (asia _|_ smoke, bronc | lung, xray)
# (asia _|_ dysp, smoke, lung, xray | either, tub, bronc)
# (asia _|_ dysp, either, lung, xray | smoke, tub, bronc)
# (asia _|_ dysp, either, smoke, xray | lung, tub, bronc)
# (asia _|_ dysp, either, smoke, lung | xray, tub, bronc)
# (asia _|_ either, smoke, lung, xray | dysp, tub, bronc)
# (asia _|_ dysp, xray | either, smoke, bronc)
# (asia _|_ dysp, smoke, xray | either, lung, bronc)
# (asia _|_ dysp | either, xray, bronc)
# (asia _|_ xray | dysp, either, bronc)
# (asia _|_ smoke | xray, lung, bronc)
# (asia _|_ smoke | dysp, lung, bronc)
# (asia _|_ bronc, dysp, lung, xray | either, smoke, tub)
# (asia _|_ bronc, dysp, smoke, xray | either, lung, tub)
# (asia _|_ dysp, smoke, lung, bronc | either, xray, tub)
# (asia _|_ bronc, smoke, lung, xray | dysp, either, tub)
# (asia _|_ bronc, dysp, either, xray | smoke, lung, tub)
# (asia _|_ dysp, either, lung, bronc | smoke, xray, tub)
# (asia _|_ bronc, either, lung, xray | dysp, smoke, tub)
# (asia _|_ dysp, either, smoke, bronc | xray, lung, tub)
# (asia _|_ bronc, either, smoke, xray | dysp, lung, tub)
# (asia _|_ either, smoke, lung, bronc | dysp, xray, tub)
# (asia _|_ bronc, dysp, xray | either, smoke, lung)
# (asia _|_ dysp, bronc | either, smoke, xray)
# (asia _|_ bronc, xray | dysp, either, smoke)
# (asia _|_ dysp, smoke, bronc | either, lung, xray)
# (asia _|_ bronc, smoke, xray | dysp, either, lung)
# (asia _|_ bronc | smoke, lung, xray)
# (asia _|_ dysp, lung, xray | either, smoke, tub, bronc)
# (asia _|_ dysp, smoke, xray | lung, either, tub, bronc)
# (asia _|_ dysp, smoke, lung | xray, either, tub, bronc)
# (asia _|_ smoke, lung, xray | dysp, either, tub, bronc)
# (asia _|_ dysp, either, xray | lung, smoke, tub, bronc)
# (asia _|_ dysp, either, lung | xray, smoke, tub, bronc)
# (asia _|_ either, lung, xray | dysp, smoke, tub, bronc)
# (asia _|_ dysp, either, smoke | xray, lung, tub, bronc)
# (asia _|_ either, smoke, xray | dysp, lung, tub, bronc)
# (asia _|_ either, smoke, lung | xray, dysp, tub, bronc)
# (asia _|_ dysp, xray | either, smoke, lung, bronc)
# (asia _|_ dysp | either, smoke, xray, bronc)
# (asia _|_ xray | dysp, either, smoke, bronc)
# (asia _|_ dysp, smoke | xray, either, lung, bronc)
# (asia _|_ smoke, xray | dysp, either, lung, bronc)
# (asia _|_ smoke | xray, dysp, lung, bronc)
# (asia _|_ bronc, dysp, xray | either, smoke, lung, tub)
# (asia _|_ dysp, lung, bronc | either, smoke, xray, tub)
# (asia _|_ bronc, lung, xray | dysp, either, smoke, tub)
# (asia _|_ dysp, smoke, bronc | xray, either, lung, tub)
# (asia _|_ bronc, smoke, xray | dysp, either, lung, tub)
# (asia _|_ smoke, lung, bronc | dysp, either, xray, tub)
# (asia _|_ dysp, either, bronc | xray, smoke, lung, tub)
# (asia _|_ bronc, either, xray | dysp, smoke, lung, tub)
# (asia _|_ either, lung, bronc | dysp, smoke, xray, tub)
# (asia _|_ either, smoke, bronc | xray, dysp, lung, tub)
# (asia _|_ dysp, bronc | either, smoke, lung, xray)
# (asia _|_ bronc, xray | dysp, either, smoke, lung)
# (asia _|_ bronc | dysp, either, smoke, xray)
# (asia _|_ smoke, bronc | dysp, either, lung, xray)
# (asia _|_ dysp, xray | tub, bronc, either, smoke, lung)
# (asia _|_ dysp, lung | tub, bronc, either, smoke, xray)
# (asia _|_ lung, xray | tub, bronc, either, smoke, dysp)
# (asia _|_ dysp, smoke | tub, bronc, either, lung, xray)
# (asia _|_ smoke, xray | tub, bronc, either, lung, dysp)
# (asia _|_ smoke, lung | tub, bronc, either, xray, dysp)
# (asia _|_ dysp, either | tub, bronc, smoke, lung, xray)
# (asia _|_ either, xray | tub, bronc, smoke, lung, dysp)
# (asia _|_ either, lung | tub, bronc, smoke, xray, dysp)
# (asia _|_ either, smoke | tub, bronc, lung, xray, dysp)
# (asia _|_ dysp | bronc, either, smoke, lung, xray)
# (asia _|_ xray | bronc, either, smoke, lung, dysp)
# (asia _|_ smoke | bronc, either, lung, xray, dysp)
# (asia _|_ dysp, bronc | tub, either, smoke, lung, xray)
# (asia _|_ bronc, xray | tub, either, smoke, lung, dysp)
# (asia _|_ lung, bronc | tub, either, smoke, xray, dysp)
# (asia _|_ smoke, bronc | tub, either, lung, xray, dysp)
# (asia _|_ either, bronc | tub, smoke, lung, xray, dysp)
# (asia _|_ bronc | either, smoke, lung, xray, dysp)
# (asia _|_ dysp | tub, bronc, either, smoke, lung, xray)
# (asia _|_ xray | tub, bronc, either, smoke, lung, dysp)
# (asia _|_ lung | tub, bronc, either, smoke, xray, dysp)
# (asia _|_ smoke | tub, bronc, either, lung, xray, dysp)
# (asia _|_ either | tub, bronc, smoke, lung, xray, dysp)
# (asia _|_ bronc | tub, either, smoke, lung, xray, dysp)
# (tub _|_ smoke, lung, bronc)
# (tub _|_ smoke, lung, bronc | asia)
# (tub _|_ smoke, lung | bronc)
# (tub _|_ xray | either)
# (tub _|_ lung, bronc | smoke)
# (tub _|_ smoke, bronc | lung)
# (tub _|_ smoke, lung | asia, bronc)
# (tub _|_ xray | asia, either)
# (tub _|_ lung, bronc | asia, smoke)
# (tub _|_ smoke, bronc | asia, lung)
# (tub _|_ dysp, xray | either, bronc)
# (tub _|_ lung | smoke, bronc)
# (tub _|_ smoke | lung, bronc)
# (tub _|_ dysp, xray, bronc | either, smoke)
# (tub _|_ dysp, smoke, xray, bronc | either, lung)
# (tub _|_ xray | dysp, either)
# (tub _|_ bronc | smoke, lung)
# (tub _|_ bronc | smoke, xray)
# (tub _|_ smoke, bronc | lung, xray)
# (tub _|_ dysp, xray | asia, either, bronc)
# (tub _|_ lung | asia, smoke, bronc)
# (tub _|_ smoke | asia, lung, bronc)
# (tub _|_ bronc, dysp, xray | asia, either, smoke)
# (tub _|_ bronc, dysp, smoke, xray | asia, either, lung)
# (tub _|_ xray | asia, either, dysp)
# (tub _|_ bronc | asia, smoke, lung)
# (tub _|_ bronc | asia, smoke, xray)
# (tub _|_ smoke, bronc | asia, lung, xray)
# (tub _|_ dysp, xray | either, smoke, bronc)
# (tub _|_ dysp, smoke, xray | either, lung, bronc)
# (tub _|_ dysp | either, xray, bronc)
# (tub _|_ xray | dysp, either, bronc)
# (tub _|_ smoke | xray, lung, bronc)
# (tub _|_ smoke | dysp, lung, bronc)
# (tub _|_ bronc, dysp, xray | either, smoke, lung)
# (tub _|_ dysp, bronc | either, smoke, xray)
# (tub _|_ bronc, xray | dysp, either, smoke)
# (tub _|_ dysp, smoke, bronc | either, lung, xray)
# (tub _|_ bronc, smoke, xray | dysp, either, lung)
# (tub _|_ bronc | smoke, lung, xray)
# (tub _|_ dysp, xray | asia, either, smoke, bronc)
# (tub _|_ dysp, smoke, xray | asia, either, lung, bronc)
# (tub _|_ dysp | asia, either, xray, bronc)
# (tub _|_ xray | dysp, asia, either, bronc)
# (tub _|_ smoke | xray, asia, lung, bronc)
# (tub _|_ smoke | dysp, asia, lung, bronc)
# (tub _|_ bronc, dysp, xray | asia, either, smoke, lung)
# (tub _|_ dysp, bronc | asia, either, smoke, xray)
# (tub _|_ bronc, xray | asia, either, smoke, dysp)
# (tub _|_ dysp, smoke, bronc | asia, either, lung, xray)
# (tub _|_ bronc, smoke, xray | asia, either, lung, dysp)
# (tub _|_ bronc | asia, smoke, lung, xray)
# (tub _|_ dysp, xray | either, smoke, lung, bronc)
# (tub _|_ dysp | either, smoke, xray, bronc)
# (tub _|_ xray | dysp, either, smoke, bronc)
# (tub _|_ dysp, smoke | xray, either, lung, bronc)
# (tub _|_ smoke, xray | dysp, either, lung, bronc)
# (tub _|_ smoke | xray, dysp, lung, bronc)
# (tub _|_ dysp, bronc | either, smoke, lung, xray)
# (tub _|_ bronc, xray | dysp, either, smoke, lung)
# (tub _|_ bronc | dysp, either, smoke, xray)
# (tub _|_ smoke, bronc | dysp, either, lung, xray)
# (tub _|_ dysp, xray | asia, bronc, either, smoke, lung)
# (tub _|_ dysp | asia, bronc, either, smoke, xray)
# (tub _|_ xray | asia, bronc, either, smoke, dysp)
# (tub _|_ dysp, smoke | asia, bronc, either, lung, xray)
# (tub _|_ smoke, xray | asia, bronc, either, lung, dysp)
# (tub _|_ smoke | asia, bronc, lung, xray, dysp)
# (tub _|_ dysp, bronc | asia, either, smoke, lung, xray)
# (tub _|_ bronc, xray | asia, either, smoke, lung, dysp)
# (tub _|_ bronc | asia, either, smoke, xray, dysp)
# (tub _|_ smoke, bronc | asia, either, lung, xray, dysp)
# (tub _|_ dysp | bronc, either, smoke, lung, xray)
# (tub _|_ xray | bronc, either, smoke, lung, dysp)
# (tub _|_ smoke | bronc, either, lung, xray, dysp)
# (tub _|_ bronc | either, smoke, lung, xray, dysp)
# (tub _|_ dysp | asia, bronc, either, smoke, lung, xray)
# (tub _|_ xray | asia, bronc, either, smoke, lung, dysp)
# (tub _|_ smoke | asia, bronc, either, lung, xray, dysp)
# (tub _|_ bronc | asia, either, smoke, lung, xray, dysp)
# (smoke _|_ asia, tub)
# (smoke _|_ tub | asia)
# (smoke _|_ asia, tub | bronc)
# (smoke _|_ asia | tub)
# (smoke _|_ xray | either)
# (smoke _|_ asia, either, xray, tub | lung)
# (smoke _|_ tub | asia, bronc)
# (smoke _|_ xray | asia, either)
# (smoke _|_ either, xray, tub | asia, lung)
# (smoke _|_ asia | tub, bronc)
# (smoke _|_ dysp, xray | either, bronc)
# (smoke _|_ either, xray, dysp, asia, tub | lung, bronc)
# (smoke _|_ asia, xray | either, tub)
# (smoke _|_ asia, either, xray | lung, tub)
# (smoke _|_ asia | xray, tub)
# (smoke _|_ asia | dysp, tub)
# (smoke _|_ asia, xray, tub | either, lung)
# (smoke _|_ xray | dysp, either)
# (smoke _|_ asia, either, tub | lung, xray)
# (smoke _|_ dysp, xray | asia, either, bronc)
# (smoke _|_ dysp, either, tub, xray | asia, lung, bronc)
# (smoke _|_ xray | asia, either, tub)
# (smoke _|_ either, xray | asia, lung, tub)
# (smoke _|_ tub, xray | asia, either, lung)
# (smoke _|_ xray | asia, either, dysp)
# (smoke _|_ either, tub | asia, lung, xray)
# (smoke _|_ asia, dysp, xray | either, tub, bronc)
# (smoke _|_ asia, dysp, either, xray | lung, tub, bronc)
# (smoke _|_ asia | xray, tub, bronc)
# (smoke _|_ asia | dysp, tub, bronc)
# (smoke _|_ asia, dysp, tub, xray | either, lung, bronc)
# (smoke _|_ dysp | either, xray, bronc)
# (smoke _|_ xray | dysp, either, bronc)
# (smoke _|_ asia, dysp, either, tub | xray, lung, bronc)
# (smoke _|_ asia, either, tub, xray | dysp, lung, bronc)
# (smoke _|_ asia, xray | either, lung, tub)
# (smoke _|_ asia | either, xray, tub)
# (smoke _|_ asia, xray | dysp, either, tub)
# (smoke _|_ asia, either | xray, lung, tub)
# (smoke _|_ asia | dysp, lung, tub)
# (smoke _|_ asia | dysp, xray, tub)
# (smoke _|_ asia, tub | either, lung, xray)
# (smoke _|_ asia, tub, xray | dysp, either, lung)
# (smoke _|_ dysp, xray | asia, either, tub, bronc)
# (smoke _|_ dysp, either, xray | asia, lung, tub, bronc)
# (smoke _|_ dysp, tub, xray | asia, either, lung, bronc)
# (smoke _|_ dysp | asia, either, xray, bronc)
# (smoke _|_ xray | dysp, asia, either, bronc)
# (smoke _|_ dysp, either, tub | xray, asia, lung, bronc)
# (smoke _|_ either, tub, xray | dysp, asia, lung, bronc)
# (smoke _|_ xray | asia, either, lung, tub)
# (smoke _|_ xray | dysp, asia, either, tub)
# (smoke _|_ either | xray, asia, lung, tub)
# (smoke _|_ tub | asia, either, lung, xray)
# (smoke _|_ tub, xray | asia, either, lung, dysp)
# (smoke _|_ asia, dysp, xray | lung, either, tub, bronc)
# (smoke _|_ asia, dysp | xray, either, tub, bronc)
# (smoke _|_ asia, xray | dysp, either, tub, bronc)
# (smoke _|_ asia, either, dysp | xray, lung, tub, bronc)
# (smoke _|_ asia, either, xray | dysp, lung, tub, bronc)
# (smoke _|_ asia | xray, dysp, tub, bronc)
# (smoke _|_ asia, dysp, tub | xray, either, lung, bronc)
# (smoke _|_ asia, tub, xray | dysp, either, lung, bronc)
# (smoke _|_ asia, either, tub | xray, dysp, lung, bronc)
# (smoke _|_ asia | xray, either, lung, tub)
# (smoke _|_ asia, xray | dysp, either, lung, tub)
# (smoke _|_ asia | dysp, either, xray, tub)
# (smoke _|_ asia | xray, dysp, lung, tub)
# (smoke _|_ asia, tub | dysp, either, lung, xray)
# (smoke _|_ dysp, xray | asia, tub, bronc, either, lung)
# (smoke _|_ dysp | asia, tub, bronc, either, xray)
# (smoke _|_ xray | asia, tub, bronc, either, dysp)
# (smoke _|_ dysp, either | asia, tub, bronc, lung, xray)
# (smoke _|_ either, xray | asia, tub, bronc, lung, dysp)
# (smoke _|_ dysp, tub | asia, bronc, either, lung, xray)
# (smoke _|_ tub, xray | asia, bronc, either, lung, dysp)
# (smoke _|_ either, tub | asia, bronc, lung, xray, dysp)
# (smoke _|_ xray | asia, tub, either, lung, dysp)
# (smoke _|_ tub | asia, either, lung, xray, dysp)
# (smoke _|_ asia, dysp | tub, bronc, either, lung, xray)
# (smoke _|_ asia, xray | tub, bronc, either, lung, dysp)
# (smoke _|_ asia | tub, bronc, either, xray, dysp)
# (smoke _|_ asia, either | tub, bronc, lung, xray, dysp)
# (smoke _|_ asia, tub | bronc, either, lung, xray, dysp)
# (smoke _|_ asia | tub, either, lung, xray, dysp)
# (smoke _|_ dysp | asia, tub, bronc, either, lung, xray)
# (smoke _|_ xray | asia, tub, bronc, either, lung, dysp)
# (smoke _|_ either | asia, tub, bronc, lung, xray, dysp)
# (smoke _|_ tub | asia, bronc, either, lung, xray, dysp)
# (smoke _|_ asia | tub, bronc, either, lung, xray, dysp)
# (lung _|_ asia, tub)
# (lung _|_ tub | asia)
# (lung _|_ asia, tub | bronc)
# (lung _|_ asia | tub)
# (lung _|_ xray | either)
# (lung _|_ bronc, asia, tub | smoke)
# (lung _|_ tub | asia, bronc)
# (lung _|_ xray | asia, either)
# (lung _|_ bronc, tub | asia, smoke)
# (lung _|_ asia | tub, bronc)
# (lung _|_ dysp, xray | either, bronc)
# (lung _|_ asia, tub | smoke, bronc)
# (lung _|_ asia, xray | either, tub)
# (lung _|_ asia, bronc | smoke, tub)
# (lung _|_ asia | xray, tub)
# (lung _|_ asia | dysp, tub)
# (lung _|_ dysp, xray, bronc | either, smoke)
# (lung _|_ xray | dysp, either)
# (lung _|_ bronc | smoke, xray)
# (lung _|_ dysp, xray | asia, either, bronc)
# (lung _|_ tub | asia, smoke, bronc)
# (lung _|_ xray | asia, either, tub)
# (lung _|_ bronc | asia, smoke, tub)
# (lung _|_ bronc, dysp, xray | asia, either, smoke)
# (lung _|_ xray | asia, either, dysp)
# (lung _|_ bronc | asia, smoke, xray)
# (lung _|_ asia, dysp, xray | either, tub, bronc)
# (lung _|_ asia | smoke, tub, bronc)
# (lung _|_ asia | xray, tub, bronc)
# (lung _|_ asia | dysp, tub, bronc)
# (lung _|_ dysp, xray | either, smoke, bronc)
# (lung _|_ dysp | either, xray, bronc)
# (lung _|_ xray | dysp, either, bronc)
# (lung _|_ asia, dysp, bronc, xray | either, smoke, tub)
# (lung _|_ asia | either, xray, tub)
# (lung _|_ asia, xray | dysp, either, tub)
# (lung _|_ asia, bronc | smoke, xray, tub)
# (lung _|_ asia | dysp, smoke, tub)
# (lung _|_ asia | dysp, xray, tub)
# (lung _|_ dysp, bronc | either, smoke, xray)
# (lung _|_ bronc, xray | dysp, either, smoke)
# (lung _|_ dysp, xray | asia, either, tub, bronc)
# (lung _|_ dysp, xray | asia, either, smoke, bronc)
# (lung _|_ dysp | asia, either, xray, bronc)
# (lung _|_ xray | dysp, asia, either, bronc)
# (lung _|_ bronc, dysp, xray | asia, either, smoke, tub)
# (lung _|_ xray | dysp, asia, either, tub)
# (lung _|_ bronc | asia, smoke, xray, tub)
# (lung _|_ dysp, bronc | asia, either, smoke, xray)
# (lung _|_ bronc, xray | asia, either, smoke, dysp)
# (lung _|_ asia, dysp, xray | either, smoke, tub, bronc)
# (lung _|_ asia, dysp | xray, either, tub, bronc)
# (lung _|_ asia, xray | dysp, either, tub, bronc)
# (lung _|_ asia | xray, smoke, tub, bronc)
# (lung _|_ asia | dysp, smoke, tub, bronc)
# (lung _|_ asia | xray, dysp, tub, bronc)
# (lung _|_ dysp | either, smoke, xray, bronc)
# (lung _|_ xray | dysp, either, smoke, bronc)
# (lung _|_ asia, dysp, bronc | either, smoke, xray, tub)
# (lung _|_ bronc, asia, xray | dysp, either, smoke, tub)
# (lung _|_ asia | dysp, either, xray, tub)
# (lung _|_ asia | dysp, smoke, xray, tub)
# (lung _|_ bronc | dysp, either, smoke, xray)
# (lung _|_ dysp, xray | asia, tub, bronc, either, smoke)
# (lung _|_ dysp | asia, tub, bronc, either, xray)
# (lung _|_ xray | asia, tub, bronc, either, dysp)
# (lung _|_ dysp | asia, bronc, either, smoke, xray)
# (lung _|_ xray | asia, bronc, either, smoke, dysp)
# (lung _|_ dysp, bronc | asia, tub, either, smoke, xray)
# (lung _|_ bronc, xray | asia, tub, either, smoke, dysp)
# (lung _|_ bronc | asia, either, smoke, xray, dysp)
# (lung _|_ asia, dysp | tub, bronc, either, smoke, xray)
# (lung _|_ asia, xray | tub, bronc, either, smoke, dysp)
# (lung _|_ asia | tub, bronc, either, xray, dysp)
# (lung _|_ asia | tub, bronc, smoke, xray, dysp)
# (lung _|_ asia, bronc | tub, either, smoke, xray, dysp)
# (lung _|_ dysp | asia, tub, bronc, either, smoke, xray)
# (lung _|_ xray | asia, tub, bronc, either, smoke, dysp)
# (lung _|_ bronc | asia, tub, either, smoke, xray, dysp)
# (lung _|_ asia | tub, bronc, either, smoke, xray, dysp)
# (bronc _|_ asia, tub)
# (bronc _|_ tub | asia)
# (bronc _|_ asia | tub)
# (bronc _|_ xray | either)
# (bronc _|_ either, lung, xray, asia, tub | smoke)
# (bronc _|_ asia, either, xray, tub | lung)
# (bronc _|_ xray | asia, either)
# (bronc _|_ xray, either, lung, tub | asia, smoke)
# (bronc _|_ either, xray, tub | asia, lung)
# (bronc _|_ asia, xray | either, tub)
# (bronc _|_ asia, either, lung, xray | smoke, tub)
# (bronc _|_ asia, either, xray | lung, tub)
# (bronc _|_ asia | xray, tub)
# (bronc _|_ asia | dysp, tub)
# (bronc _|_ xray, asia, lung, tub | either, smoke)
# (bronc _|_ asia, xray, tub | either, lung)
# (bronc _|_ xray | dysp, either)
# (bronc _|_ asia, either, xray, tub | smoke, lung)
# (bronc _|_ asia, either, lung, tub | smoke, xray)
# (bronc _|_ asia, either, tub | lung, xray)
# (bronc _|_ xray | asia, either, tub)
# (bronc _|_ either, lung, xray | asia, smoke, tub)
# (bronc _|_ either, xray | asia, lung, tub)
# (bronc _|_ tub, lung, xray | asia, either, smoke)
# (bronc _|_ tub, xray | asia, either, lung)
# (bronc _|_ xray | asia, either, dysp)
# (bronc _|_ either, tub, xray | asia, smoke, lung)
# (bronc _|_ either, lung, tub | asia, smoke, xray)
# (bronc _|_ either, tub | asia, lung, xray)
# (bronc _|_ asia, lung, xray | either, smoke, tub)
# (bronc _|_ asia, xray | either, lung, tub)
# (bronc _|_ asia | either, xray, tub)
# (bronc _|_ asia, xray | dysp, either, tub)
# (bronc _|_ asia, either, xray | smoke, lung, tub)
# (bronc _|_ asia, either, lung | smoke, xray, tub)
# (bronc _|_ asia | dysp, smoke, tub)
# (bronc _|_ asia, either | xray, lung, tub)
# (bronc _|_ asia | dysp, lung, tub)
# (bronc _|_ asia | dysp, xray, tub)
# (bronc _|_ asia, tub, xray | either, smoke, lung)
# (bronc _|_ asia, lung, tub | either, smoke, xray)
# (bronc _|_ asia, tub, lung, xray | dysp, either, smoke)
# (bronc _|_ asia, tub | either, lung, xray)
# (bronc _|_ asia, tub, xray | dysp, either, lung)
# (bronc _|_ asia, either, tub | smoke, lung, xray)
# (bronc _|_ lung, xray | asia, either, smoke, tub)
# (bronc _|_ xray | asia, either, lung, tub)
# (bronc _|_ xray | dysp, asia, either, tub)
# (bronc _|_ either, xray | asia, smoke, lung, tub)
# (bronc _|_ either, lung | asia, smoke, xray, tub)
# (bronc _|_ either | xray, asia, lung, tub)
# (bronc _|_ tub, xray | asia, either, smoke, lung)
# (bronc _|_ lung, tub | asia, either, smoke, xray)
# (bronc _|_ tub, lung, xray | asia, either, smoke, dysp)
# (bronc _|_ tub | asia, either, lung, xray)
# (bronc _|_ tub, xray | asia, either, lung, dysp)
# (bronc _|_ either, tub | asia, smoke, lung, xray)
# (bronc _|_ asia, xray | either, smoke, lung, tub)
# (bronc _|_ asia, lung | either, smoke, xray, tub)
# (bronc _|_ asia, lung, xray | dysp, either, smoke, tub)
# (bronc _|_ asia | xray, either, lung, tub)
# (bronc _|_ asia, xray | dysp, either, lung, tub)
# (bronc _|_ asia | dysp, either, xray, tub)
# (bronc _|_ asia, either | xray, smoke, lung, tub)
# (bronc _|_ asia | dysp, smoke, lung, tub)
# (bronc _|_ asia | dysp, smoke, xray, tub)
# (bronc _|_ asia | xray, dysp, lung, tub)
# (bronc _|_ asia, tub | either, smoke, lung, xray)
# (bronc _|_ asia, tub, xray | dysp, either, smoke, lung)
# (bronc _|_ asia, lung, tub | dysp, either, smoke, xray)
# (bronc _|_ asia, tub | dysp, either, lung, xray)
# (bronc _|_ xray | asia, tub, either, smoke, lung)
# (bronc _|_ lung | asia, tub, either, smoke, xray)
# (bronc _|_ lung, xray | asia, tub, either, smoke, dysp)
# (bronc _|_ xray | asia, tub, either, lung, dysp)
# (bronc _|_ either | asia, tub, smoke, lung, xray)
# (bronc _|_ tub | asia, either, smoke, lung, xray)
# (bronc _|_ tub, xray | asia, either, smoke, lung, dysp)
# (bronc _|_ lung, tub | asia, either, smoke, xray, dysp)
# (bronc _|_ tub | asia, either, lung, xray, dysp)
# (bronc _|_ asia | tub, either, smoke, lung, xray)
# (bronc _|_ asia, xray | tub, either, smoke, lung, dysp)
# (bronc _|_ asia, lung | tub, either, smoke, xray, dysp)
# (bronc _|_ asia | tub, either, lung, xray, dysp)
# (bronc _|_ asia | tub, smoke, lung, xray, dysp)
# (bronc _|_ asia, tub | either, smoke, lung, xray, dysp)
# (bronc _|_ xray | asia, tub, either, smoke, lung, dysp)
# (bronc _|_ lung | asia, tub, either, smoke, xray, dysp)
# (bronc _|_ tub | asia, either, smoke, lung, xray, dysp)
# (bronc _|_ asia | tub, either, smoke, lung, xray, dysp)
# (either _|_ asia | tub)
# (either _|_ bronc | smoke)
# (either _|_ smoke, bronc | lung)
# (either _|_ bronc | asia, smoke)
# (either _|_ smoke, bronc | asia, lung)
# (either _|_ asia | tub, bronc)
# (either _|_ smoke | lung, bronc)
# (either _|_ asia, bronc | smoke, tub)
# (either _|_ asia, smoke, bronc | lung, tub)
# (either _|_ asia | xray, tub)
# (either _|_ asia | dysp, tub)
# (either _|_ bronc | smoke, lung)
# (either _|_ bronc | smoke, xray)
# (either _|_ smoke, bronc | lung, xray)
# (either _|_ smoke | asia, lung, bronc)
# (either _|_ bronc | asia, smoke, tub)
# (either _|_ smoke, bronc | asia, lung, tub)
# (either _|_ bronc | asia, smoke, lung)
# (either _|_ bronc | asia, smoke, xray)
# (either _|_ smoke, bronc | asia, lung, xray)
# (either _|_ asia | smoke, tub, bronc)
# (either _|_ asia, smoke | lung, tub, bronc)
# (either _|_ asia | xray, tub, bronc)
# (either _|_ asia | dysp, tub, bronc)
# (either _|_ smoke | xray, lung, bronc)
# (either _|_ smoke | dysp, lung, bronc)
# (either _|_ asia, bronc | smoke, lung, tub)
# (either _|_ asia, bronc | smoke, xray, tub)
# (either _|_ asia | dysp, smoke, tub)
# (either _|_ asia, smoke, bronc | xray, lung, tub)
# (either _|_ asia | dysp, lung, tub)
# (either _|_ asia | dysp, xray, tub)
# (either _|_ bronc | smoke, lung, xray)
# (either _|_ smoke | asia, lung, tub, bronc)
# (either _|_ smoke | xray, asia, lung, bronc)
# (either _|_ smoke | dysp, asia, lung, bronc)
# (either _|_ bronc | asia, smoke, lung, tub)
# (either _|_ bronc | asia, smoke, xray, tub)
# (either _|_ smoke, bronc | xray, asia, lung, tub)
# (either _|_ bronc | asia, smoke, lung, xray)
# (either _|_ asia | lung, smoke, tub, bronc)
# (either _|_ asia | xray, smoke, tub, bronc)
# (either _|_ asia | dysp, smoke, tub, bronc)
# (either _|_ asia, smoke | xray, lung, tub, bronc)
# (either _|_ asia, smoke | dysp, lung, tub, bronc)
# (either _|_ asia | xray, dysp, tub, bronc)
# (either _|_ smoke | xray, dysp, lung, bronc)
# (either _|_ asia, bronc | xray, smoke, lung, tub)
# (either _|_ asia | dysp, smoke, lung, tub)
# (either _|_ asia | dysp, smoke, xray, tub)
# (either _|_ asia | xray, dysp, lung, tub)
# (either _|_ smoke | asia, tub, bronc, lung, xray)
# (either _|_ smoke | asia, tub, bronc, lung, dysp)
# (either _|_ smoke | asia, bronc, lung, xray, dysp)
# (either _|_ bronc | asia, tub, smoke, lung, xray)
# (either _|_ asia | tub, bronc, smoke, lung, xray)
# (either _|_ asia | tub, bronc, smoke, lung, dysp)
# (either _|_ asia | tub, bronc, smoke, xray, dysp)
# (either _|_ asia, smoke | tub, bronc, lung, xray, dysp)
# (either _|_ asia | tub, smoke, lung, xray, dysp)
# (either _|_ smoke | asia, tub, bronc, lung, xray, dysp)
# (either _|_ asia | tub, bronc, smoke, lung, xray, dysp)
# (xray _|_ asia | tub)
# (xray _|_ smoke, tub, lung, dysp, asia, bronc | either)
# (xray _|_ bronc | smoke)
# (xray _|_ smoke, bronc | lung)
# (xray _|_ smoke, tub, lung, dysp, bronc | asia, either)
# (xray _|_ bronc | asia, smoke)
# (xray _|_ smoke, bronc | asia, lung)
# (xray _|_ asia | tub, bronc)
# (xray _|_ smoke, lung, dysp, asia, tub | either, bronc)
# (xray _|_ smoke | lung, bronc)
# (xray _|_ smoke, lung, dysp, asia, bronc | either, tub)
# (xray _|_ asia, bronc | smoke, tub)
# (xray _|_ asia, smoke, bronc | lung, tub)
# (xray _|_ asia | dysp, tub)
# (xray _|_ tub, lung, dysp, asia, bronc | either, smoke)
# (xray _|_ smoke, tub, dysp, asia, bronc | either, lung)
# (xray _|_ smoke, tub, lung, asia, bronc | dysp, either)
# (xray _|_ bronc | smoke, lung)
# (xray _|_ dysp, smoke, lung, tub | asia, either, bronc)
# (xray _|_ smoke | asia, lung, bronc)
# (xray _|_ dysp, smoke, lung, bronc | asia, either, tub)
# (xray _|_ bronc | asia, smoke, tub)
# (xray _|_ smoke, bronc | asia, lung, tub)
# (xray _|_ bronc, dysp, lung, tub | asia, either, smoke)
# (xray _|_ bronc, dysp, smoke, tub | asia, either, lung)
# (xray _|_ bronc, smoke, lung, tub | asia, either, dysp)
# (xray _|_ bronc | asia, smoke, lung)
# (xray _|_ asia, smoke, lung, dysp | either, tub, bronc)
# (xray _|_ asia | smoke, tub, bronc)
# (xray _|_ asia, smoke | lung, tub, bronc)
# (xray _|_ asia | dysp, tub, bronc)
# (xray _|_ asia, dysp, lung, tub | either, smoke, bronc)
# (xray _|_ asia, dysp, smoke, tub | either, lung, bronc)
# (xray _|_ asia, smoke, lung, tub | dysp, either, bronc)
# (xray _|_ smoke | dysp, lung, bronc)
# (xray _|_ asia, dysp, lung, bronc | either, smoke, tub)
# (xray _|_ asia, dysp, smoke, bronc | either, lung, tub)
# (xray _|_ asia, smoke, lung, bronc | dysp, either, tub)
# (xray _|_ asia, bronc | smoke, lung, tub)
# (xray _|_ asia | dysp, smoke, tub)
# (xray _|_ asia | dysp, lung, tub)
# (xray _|_ asia, dysp, bronc, tub | either, smoke, lung)
# (xray _|_ bronc, asia, lung, tub | dysp, either, smoke)
# (xray _|_ bronc, asia, smoke, tub | dysp, either, lung)
# (xray _|_ dysp, smoke, lung | asia, either, tub, bronc)
# (xray _|_ smoke | asia, lung, tub, bronc)
# (xray _|_ dysp, lung, tub | asia, either, smoke, bronc)
# (xray _|_ dysp, smoke, tub | asia, either, lung, bronc)
# (xray _|_ smoke, lung, tub | dysp, asia, either, bronc)
# (xray _|_ smoke | dysp, asia, lung, bronc)
# (xray _|_ dysp, lung, bronc | asia, either, smoke, tub)
# (xray _|_ dysp, smoke, bronc | asia, either, lung, tub)
# (xray _|_ smoke, lung, bronc | dysp, asia, either, tub)
# (xray _|_ bronc | asia, smoke, lung, tub)
# (xray _|_ bronc, dysp, tub | asia, either, smoke, lung)
# (xray _|_ bronc, lung, tub | asia, either, smoke, dysp)
# (xray _|_ bronc, smoke, tub | asia, either, lung, dysp)
# (xray _|_ asia, lung, dysp | either, smoke, tub, bronc)
# (xray _|_ asia, smoke, dysp | lung, either, tub, bronc)
# (xray _|_ asia, smoke, lung | dysp, either, tub, bronc)
# (xray _|_ asia | lung, smoke, tub, bronc)
# (xray _|_ asia | dysp, smoke, tub, bronc)
# (xray _|_ asia, smoke | dysp, lung, tub, bronc)
# (xray _|_ asia, dysp, tub | either, smoke, lung, bronc)
# (xray _|_ asia, lung, tub | dysp, either, smoke, bronc)
# (xray _|_ asia, smoke, tub | dysp, either, lung, bronc)
# (xray _|_ asia, dysp, bronc | either, smoke, lung, tub)
# (xray _|_ asia, lung, bronc | dysp, either, smoke, tub)
# (xray _|_ asia, smoke, bronc | dysp, either, lung, tub)
# (xray _|_ asia | dysp, smoke, lung, tub)
# (xray _|_ bronc, asia, tub | dysp, either, smoke, lung)
# (xray _|_ dysp, lung | asia, tub, bronc, either, smoke)
# (xray _|_ dysp, smoke | asia, tub, bronc, either, lung)
# (xray _|_ smoke, lung | asia, tub, bronc, either, dysp)
# (xray _|_ smoke | asia, tub, bronc, lung, dysp)
# (xray _|_ dysp, tub | asia, bronc, either, smoke, lung)
# (xray _|_ lung, tub | asia, bronc, either, smoke, dysp)
# (xray _|_ smoke, tub | asia, bronc, either, lung, dysp)
# (xray _|_ dysp, bronc | asia, tub, either, smoke, lung)
# (xray _|_ lung, bronc | asia, tub, either, smoke, dysp)
# (xray _|_ smoke, bronc | asia, tub, either, lung, dysp)
# (xray _|_ bronc, tub | asia, either, smoke, lung, dysp)
# (xray _|_ asia, dysp | tub, bronc, either, smoke, lung)
# (xray _|_ asia, lung | tub, bronc, either, smoke, dysp)
# (xray _|_ asia, smoke | tub, bronc, either, lung, dysp)
# (xray _|_ asia | tub, bronc, smoke, lung, dysp)
# (xray _|_ asia, tub | bronc, either, smoke, lung, dysp)
# (xray _|_ asia, bronc | tub, either, smoke, lung, dysp)
# (xray _|_ dysp | asia, tub, bronc, either, smoke, lung)
# (xray _|_ lung | asia, tub, bronc, either, smoke, dysp)
# (xray _|_ smoke | asia, tub, bronc, either, lung, dysp)
# (xray _|_ tub | asia, bronc, either, smoke, lung, dysp)
# (xray _|_ bronc | asia, tub, either, smoke, lung, dysp)
# (xray _|_ asia | tub, bronc, either, smoke, lung, dysp)
# (dysp _|_ asia | tub)
# (dysp _|_ xray | either)
# (dysp _|_ xray | asia, either)
# (dysp _|_ asia | tub, bronc)
# (dysp _|_ smoke, lung, xray, asia, tub | either, bronc)
# (dysp _|_ smoke | lung, bronc)
# (dysp _|_ asia, xray | either, tub)
# (dysp _|_ asia | smoke, tub)
# (dysp _|_ asia | lung, tub)
# (dysp _|_ asia | xray, tub)
# (dysp _|_ xray, asia, lung, tub | either, smoke)
# (dysp _|_ asia, xray, tub | either, lung)
# (dysp _|_ tub, smoke, lung, xray | asia, either, bronc)
# (dysp _|_ smoke | asia, lung, bronc)
# (dysp _|_ xray | asia, either, tub)
# (dysp _|_ tub, lung, xray | asia, either, smoke)
# (dysp _|_ tub, xray | asia, either, lung)
# (dysp _|_ asia, smoke, lung, xray | either, tub, bronc)
# (dysp _|_ asia | smoke, tub, bronc)
# (dysp _|_ asia, smoke | lung, tub, bronc)
# (dysp _|_ asia | xray, tub, bronc)
# (dysp _|_ asia, tub, lung, xray | either, smoke, bronc)
# (dysp _|_ asia, smoke, tub, xray | either, lung, bronc)
# (dysp _|_ asia, smoke, lung, tub | either, xray, bronc)
# (dysp _|_ smoke | xray, lung, bronc)
# (dysp _|_ asia, lung, xray | either, smoke, tub)
# (dysp _|_ asia, xray | either, lung, tub)
# (dysp _|_ asia | either, xray, tub)
# (dysp _|_ asia | smoke, lung, tub)
# (dysp _|_ asia | smoke, xray, tub)
# (dysp _|_ asia | xray, lung, tub)
# (dysp _|_ asia, tub, xray | either, smoke, lung)
# (dysp _|_ asia, lung, tub | either, smoke, xray)
# (dysp _|_ asia, tub | either, lung, xray)
# (dysp _|_ smoke, lung, xray | asia, either, tub, bronc)
# (dysp _|_ smoke | asia, lung, tub, bronc)
# (dysp _|_ tub, lung, xray | asia, either, smoke, bronc)
# (dysp _|_ smoke, tub, xray | asia, either, lung, bronc)
# (dysp _|_ smoke, lung, tub | asia, either, xray, bronc)
# (dysp _|_ smoke | xray, asia, lung, bronc)
# (dysp _|_ lung, xray | asia, either, smoke, tub)
# (dysp _|_ xray | asia, either, lung, tub)
# (dysp _|_ tub, xray | asia, either, smoke, lung)
# (dysp _|_ lung, tub | asia, either, smoke, xray)
# (dysp _|_ tub | asia, either, lung, xray)
# (dysp _|_ asia, lung, xray | either, smoke, tub, bronc)
# (dysp _|_ asia, smoke, xray | lung, either, tub, bronc)
# (dysp _|_ asia, smoke, lung | xray, either, tub, bronc)
# (dysp _|_ asia | lung, smoke, tub, bronc)
# (dysp _|_ asia | xray, smoke, tub, bronc)
# (dysp _|_ asia, smoke | xray, lung, tub, bronc)
# (dysp _|_ asia, tub, xray | either, smoke, lung, bronc)
# (dysp _|_ asia, lung, tub | either, smoke, xray, bronc)
# (dysp _|_ asia, smoke, tub | xray, either, lung, bronc)
# (dysp _|_ asia, xray | either, smoke, lung, tub)
# (dysp _|_ asia, lung | either, smoke, xray, tub)
# (dysp _|_ asia | xray, either, lung, tub)
# (dysp _|_ asia | xray, smoke, lung, tub)
# (dysp _|_ asia, tub | either, smoke, lung, xray)
# (dysp _|_ lung, xray | asia, tub, bronc, either, smoke)
# (dysp _|_ smoke, xray | asia, tub, bronc, either, lung)
# (dysp _|_ smoke, lung | asia, tub, bronc, either, xray)
# (dysp _|_ smoke | asia, tub, bronc, lung, xray)
# (dysp _|_ tub, xray | asia, bronc, either, smoke, lung)
# (dysp _|_ lung, tub | asia, bronc, either, smoke, xray)
# (dysp _|_ smoke, tub | asia, bronc, either, lung, xray)
# (dysp _|_ xray | asia, tub, either, smoke, lung)
# (dysp _|_ lung | asia, tub, either, smoke, xray)
# (dysp _|_ tub | asia, either, smoke, lung, xray)
# (dysp _|_ asia, xray | tub, bronc, either, smoke, lung)
# (dysp _|_ asia, lung | tub, bronc, either, smoke, xray)
# (dysp _|_ asia, smoke | tub, bronc, either, lung, xray)
# (dysp _|_ asia | tub, bronc, smoke, lung, xray)
# (dysp _|_ asia, tub | bronc, either, smoke, lung, xray)
# (dysp _|_ asia | tub, either, smoke, lung, xray)
# (dysp _|_ xray | asia, tub, bronc, either, smoke, lung)
# (dysp _|_ lung | asia, tub, bronc, either, smoke, xray)
# (dysp _|_ smoke | asia, tub, bronc, either, lung, xray)
# (dysp _|_ tub | asia, bronc, either, smoke, lung, xray)
# (dysp _|_ asia | tub, bronc, either, smoke, lung, xray)

# %% [markdown]
# ## Make Inferences

# %% [markdown]
# **Q1.** What is the probability of a person having bronchitis given that he/she doesn't smoke?

# %%
# initialise inference class
infer = VariableElimination(asia_model)

# make query
bronchitis = infer.query(variables=['bronc'], evidence={'smoke': 0},joint=False )

# print result
print(bronchitis['bronc'])
# Out:
# Finding Elimination Order: : 100%|█████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1500.38it/s]
# Eliminating: tub: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 239.99it/s]
# +------------+--------------+
# | bronc      |   phi(bronc) |
# +============+==============+
# | bronc(yes) |       0.6000 |
# +------------+--------------+
# | bronc(no)  |       0.4000 |
# +------------+--------------+

# %% [markdown]
# What is the probability that the person is a smoker given that their x-ray result is positive?

# %% [markdown]
# **Q2.** What is the probability that the person is a smoker given that their x-ray result is positive

# %%
smoker = infer.query(variables=['smoke'], evidence={'xray': 1},joint=False )
print(smoker['smoke'])
# Out:
# Finding Elimination Order: : 100%|█████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1200.09it/s]
# Eliminating: tub: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 222.22it/s]
# +------------+--------------+
# | smoke      |   phi(smoke) |
# +============+==============+
# | smoke(yes) |       0.4767 |
# +------------+--------------+
# | smoke(no)  |       0.5233 |
# +------------+--------------+

# %% [markdown]
# **Q3.** Consider the following two probabilities:
#
# 1. The probability that a person doesn't have dyspnea given that he has bronchitis.
# 2. The probability that a person doesn't have dyspnea given that he has bronchitis and doesn't have lung cancer.
#
# By what percent does the probability increase or decrease from situation 1 to situation 2?

# %%
dyspnea_b = infer.query(variables=['dysp'], evidence={'bronc': 1},joint=False )
print(dyspnea_b['dysp'])

dyspnea_b_l = infer.query(variables=['dysp'], evidence={'bronc': 1, 'lung': 0},joint=False)
print(dyspnea_b_l['dysp'])
# Out:
# Finding Elimination Order: : 100%|██████████████████████████████████████████████████████| 6/6 [00:00<00:00, 797.70it/s]
# Eliminating: tub: 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 99.99it/s]
# +-----------+-------------+
# | dysp      |   phi(dysp) |
# +===========+=============+
# | dysp(yes) |      0.1316 |
# +-----------+-------------+
# | dysp(no)  |      0.8684 |
# +-----------+-------------+
# Finding Elimination Order: : 100%|██████████████████████████████████████████████████████| 5/5 [00:00<00:00, 714.48it/s]
# Eliminating: smoke: 100%|███████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 172.41it/s]
# +-----------+-------------+
# | dysp      |   phi(dysp) |
# +===========+=============+
# | dysp(yes) |      0.7000 |
# +-----------+-------------+
# | dysp(no)  |      0.3000 |
# +-----------+-------------+

# %% [markdown]
# Probability of not having Dyspnea changed from 13% to 70%. The percentage change is ((0.70-0.1316)*100)/(0.1316) = +431.91%
