# %% [markdown]
# ## Making Inferences in the ASIA graph

# %% [markdown]
# Notebook layout:
# 1. Load ASIA model
# 2. Make inferences

# %% [markdown]
# ## Graph
# ![ASIA Graph](ASIA.jpg)

# %% [markdown]
# ## 1. Load ASIA Model

# %%
# import essential libraries to manipulate data
import numpy as np
import pandas as pd

# import pgmpy functions
from pgmpy.readwrite import BIFReader
from pgmpy.inference import VariableElimination

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# load model
data = BIFReader('asia.bif')
asia_model = data.get_model()

# %%
# print nodes of the model
asia_model.nodes()
# Out:
# NodeView(('asia', 'tub', 'smoke', 'lung', 'bronc', 'either', 'xray', 'dysp'))

# %%
# print edges of the model
asia_model.edges()
# Out:
# OutEdgeView([('asia', 'tub'), ('tub', 'either'), ('smoke', 'lung'), ('smoke', 'bronc'), ('lung', 'either'), ('bronc', 'dysp'), ('either', 'xray'), ('either', 'dysp')])

# %%
# get model parameters
asia_model.get_cpds()
# Out:
# [<TabularCPD representing P(asia:2) at 0x29430360908>,
#  <TabularCPD representing P(bronc:2 | smoke:2) at 0x29430360b70>,
#  <TabularCPD representing P(dysp:2 | bronc:2, either:2) at 0x29430360be0>,
#  <TabularCPD representing P(either:2 | lung:2, tub:2) at 0x29430360cf8>,
#  <TabularCPD representing P(lung:2 | smoke:2) at 0x29430360ba8>,
#  <TabularCPD representing P(smoke:2) at 0x2944330fb70>,
#  <TabularCPD representing P(tub:2 | asia:2) at 0x2944330ff98>,
#  <TabularCPD representing P(xray:2 | either:2) at 0x2944330ff28>]

# %%
# print the CPDs by iterating through them
for cpd in asia_model.get_cpds():
    print("CPD of {variable}:".format(variable=cpd.variable))
    print(cpd)
    print(cpd.name_to_no)
# Out:
# CPD of asia:
# +-----------+------+
# | asia(yes) | 0.01 |
# +-----------+------+
# | asia(no)  | 0.99 |
# +-----------+------+
# {'asia': {'yes': 0, 'no': 1}}
# CPD of bronc:
# +------------+------------+-----------+
# | smoke      | smoke(yes) | smoke(no) |
# +------------+------------+-----------+
# | bronc(yes) | 0.6        | 0.3       |
# +------------+------------+-----------+
# | bronc(no)  | 0.4        | 0.7       |
# +------------+------------+-----------+
# {'smoke': {'yes': 0, 'no': 1}, 'bronc': {'yes': 0, 'no': 1}}
# CPD of dysp:
# +-----------+-------------+------------+-------------+------------+
# | bronc     | bronc(yes)  | bronc(yes) | bronc(no)   | bronc(no)  |
# +-----------+-------------+------------+-------------+------------+
# | either    | either(yes) | either(no) | either(yes) | either(no) |
# +-----------+-------------+------------+-------------+------------+
# | dysp(yes) | 0.9         | 0.8        | 0.7         | 0.1        |
# +-----------+-------------+------------+-------------+------------+
# | dysp(no)  | 0.1         | 0.2        | 0.3         | 0.9        |
# +-----------+-------------+------------+-------------+------------+
# {'bronc': {'yes': 0, 'no': 1}, 'either': {'yes': 0, 'no': 1}, 'dysp': {'yes': 0, 'no': 1}}
# CPD of either:
# +-------------+-----------+-----------+----------+----------+
# | lung        | lung(yes) | lung(yes) | lung(no) | lung(no) |
# +-------------+-----------+-----------+----------+----------+
# | tub         | tub(yes)  | tub(no)   | tub(yes) | tub(no)  |
# +-------------+-----------+-----------+----------+----------+
# | either(yes) | 1.0       | 1.0       | 1.0      | 0.0      |
# +-------------+-----------+-----------+----------+----------+
# | either(no)  | 0.0       | 0.0       | 0.0      | 1.0      |
# +-------------+-----------+-----------+----------+----------+
# {'lung': {'yes': 0, 'no': 1}, 'tub': {'yes': 0, 'no': 1}, 'either': {'yes': 0, 'no': 1}}
# CPD of lung:
# +-----------+------------+-----------+
# | smoke     | smoke(yes) | smoke(no) |
# +-----------+------------+-----------+
# | lung(yes) | 0.1        | 0.01      |
# +-----------+------------+-----------+
# | lung(no)  | 0.9        | 0.99      |
# +-----------+------------+-----------+
# {'smoke': {'yes': 0, 'no': 1}, 'lung': {'yes': 0, 'no': 1}}
# CPD of smoke:
# +------------+-----+
# | smoke(yes) | 0.5 |
# +------------+-----+
# | smoke(no)  | 0.5 |
# +------------+-----+
# {'smoke': {'yes': 0, 'no': 1}}
# CPD of tub:
# +----------+-----------+----------+
# | asia     | asia(yes) | asia(no) |
# +----------+-----------+----------+
# | tub(yes) | 0.05      | 0.01     |
# +----------+-----------+----------+
# | tub(no)  | 0.95      | 0.99     |
# +----------+-----------+----------+
# {'asia': {'yes': 0, 'no': 1}, 'tub': {'yes': 0, 'no': 1}}
# CPD of xray:
# +-----------+-------------+------------+
# | either    | either(yes) | either(no) |
# +-----------+-------------+------------+
# | xray(yes) | 0.98        | 0.05       |
# +-----------+-------------+------------+
# | xray(no)  | 0.02        | 0.95       |
# +-----------+-------------+------------+
# {'either': {'yes': 0, 'no': 1}, 'xray': {'yes': 0, 'no': 1}}

# %% [markdown]
# #### NOTE : Here the 'yes' denotes 0 and 'no' denotes 1. Because of the recent updates in pgmpy, the way it stores the variables changed too.

# %%
# get independencies
asia_model.get_independencies()
# Out:
# (asia _|_ bronc, smoke, lung)
# (asia _|_ smoke, lung | bronc)
# (asia _|_ bronc, lung | smoke)
# (asia _|_ bronc, smoke | lung)
# (asia _|_ xray | either)
# (asia _|_ bronc, either, smoke, dysp, xray, lung | tub)
# (asia _|_ lung | bronc, smoke)
# (asia _|_ smoke | bronc, lung)
# (asia _|_ dysp, xray | bronc, either)
# (asia _|_ dysp, smoke, either, xray, lung | bronc, tub)
# (asia _|_ bronc | smoke, lung)
# (asia _|_ bronc, dysp, xray | either, smoke)
# (asia _|_ bronc | smoke, xray)
# (asia _|_ bronc, either, dysp, xray, lung | smoke, tub)
# (asia _|_ bronc, dysp, smoke, xray | either, lung)
# (asia _|_ bronc, smoke | xray, lung)
# (asia _|_ bronc, either, smoke, dysp, xray | lung, tub)
# (asia _|_ xray | dysp, either)
# (asia _|_ bronc, dysp, smoke, xray, lung | either, tub)
# (asia _|_ bronc, either, smoke, xray, lung | dysp, tub)
# (asia _|_ bronc, either, smoke, dysp, lung | xray, tub)
# (asia _|_ dysp, xray | bronc, either, smoke)
# (asia _|_ dysp, xray, lung, either | bronc, smoke, tub)
# (asia _|_ dysp, smoke, xray | bronc, either, lung)
# (asia _|_ smoke | bronc, dysp, lung)
# (asia _|_ smoke | bronc, xray, lung)
# (asia _|_ dysp, smoke, xray, either | bronc, lung, tub)
# (asia _|_ xray | bronc, either, dysp)
# (asia _|_ dysp | bronc, either, xray)
# (asia _|_ dysp, smoke, xray, lung | bronc, either, tub)
# (asia _|_ either, smoke, xray, lung | bronc, dysp, tub)
# (asia _|_ dysp, smoke, lung, either | bronc, xray, tub)
# (asia _|_ bronc, dysp, xray | either, smoke, lung)
# (asia _|_ bronc | smoke, xray, lung)
# (asia _|_ bronc, either, dysp, xray | smoke, lung, tub)
# (asia _|_ bronc, xray | dysp, either, smoke)
# (asia _|_ bronc, dysp | either, smoke, xray)
# (asia _|_ bronc, dysp, xray, lung | either, smoke, tub)
# (asia _|_ bronc, either, xray, lung | dysp, smoke, tub)
# (asia _|_ bronc, either, dysp, lung | smoke, xray, tub)
# (asia _|_ bronc, smoke, xray | dysp, either, lung)
# (asia _|_ bronc, dysp, smoke | either, xray, lung)
# (asia _|_ bronc, dysp, smoke, xray | either, lung, tub)
# (asia _|_ bronc, either, smoke, xray | dysp, lung, tub)
# (asia _|_ bronc, either, smoke, dysp | xray, lung, tub)
# (asia _|_ bronc, smoke, xray, lung | dysp, either, tub)
# (asia _|_ bronc, dysp, smoke, lung | either, xray, tub)
# (asia _|_ bronc, either, smoke, lung | dysp, xray, tub)
# (asia _|_ dysp, xray | bronc, either, smoke, lung)
# (asia _|_ dysp, xray, either | bronc, smoke, lung, tub)
# (asia _|_ xray | bronc, either, smoke, dysp)
# (asia _|_ dysp | bronc, either, smoke, xray)
# (asia _|_ dysp, xray, lung | bronc, either, smoke, tub)
# (asia _|_ either, xray, lung | bronc, dysp, smoke, tub)
# (asia _|_ dysp, lung, either | bronc, smoke, xray, tub)
# (asia _|_ smoke, xray | bronc, either, dysp, lung)
# (asia _|_ dysp, smoke | bronc, either, xray, lung)
# (asia _|_ dysp, smoke, xray | bronc, either, lung, tub)
# (asia _|_ smoke | bronc, dysp, xray, lung)
# (asia _|_ either, smoke, xray | bronc, dysp, lung, tub)
# (asia _|_ dysp, smoke, either | bronc, xray, lung, tub)
# (asia _|_ smoke, xray, lung | bronc, either, dysp, tub)
# (asia _|_ dysp, smoke, lung | bronc, either, xray, tub)
# (asia _|_ either, smoke, lung | bronc, dysp, xray, tub)
# (asia _|_ bronc, xray | dysp, either, smoke, lung)
# (asia _|_ bronc, dysp | either, smoke, xray, lung)
# (asia _|_ bronc, dysp, xray | either, smoke, lung, tub)
# (asia _|_ bronc, either, xray | dysp, smoke, lung, tub)
# (asia _|_ bronc, either, dysp | smoke, xray, lung, tub)
# (asia _|_ bronc | dysp, either, smoke, xray)
# (asia _|_ bronc, xray, lung | dysp, either, smoke, tub)
# (asia _|_ bronc, dysp, lung | either, smoke, xray, tub)
# (asia _|_ bronc, either, lung | dysp, smoke, xray, tub)
# (asia _|_ bronc, smoke | dysp, either, xray, lung)
# (asia _|_ bronc, smoke, xray | dysp, either, lung, tub)
# (asia _|_ bronc, dysp, smoke | either, xray, lung, tub)
# (asia _|_ bronc, either, smoke | dysp, xray, lung, tub)
# (asia _|_ bronc, smoke, lung | dysp, either, xray, tub)
# (asia _|_ xray | bronc, smoke, lung, either, dysp)
# (asia _|_ dysp | bronc, smoke, lung, either, xray)
# (asia _|_ dysp, xray | bronc, smoke, lung, either, tub)
# (asia _|_ either, xray | bronc, smoke, lung, dysp, tub)
# (asia _|_ dysp, either | bronc, smoke, lung, xray, tub)
# (asia _|_ xray, lung | bronc, smoke, either, dysp, tub)
# (asia _|_ dysp, lung | bronc, smoke, either, xray, tub)
# (asia _|_ either, lung | bronc, smoke, dysp, xray, tub)
# (asia _|_ smoke | bronc, lung, either, dysp, xray)
# (asia _|_ smoke, xray | bronc, lung, either, dysp, tub)
# (asia _|_ dysp, smoke | bronc, lung, either, xray, tub)
# (asia _|_ either, smoke | bronc, lung, dysp, xray, tub)
# (asia _|_ smoke, lung | bronc, either, dysp, xray, tub)
# (asia _|_ bronc | smoke, lung, dysp, either, xray)
# (asia _|_ bronc, xray | smoke, lung, dysp, either, tub)
# (asia _|_ bronc, dysp | smoke, lung, either, xray, tub)
# (asia _|_ bronc, either | smoke, lung, dysp, xray, tub)
# (asia _|_ bronc, lung | smoke, dysp, either, xray, tub)
# (asia _|_ bronc, smoke | lung, dysp, either, xray, tub)
# (asia _|_ xray | bronc, smoke, lung, either, dysp, tub)
# (asia _|_ dysp | bronc, smoke, lung, either, xray, tub)
# (asia _|_ either | bronc, smoke, lung, dysp, xray, tub)
# (asia _|_ lung | bronc, smoke, either, dysp, xray, tub)
# (asia _|_ smoke | bronc, lung, either, dysp, xray, tub)
# (asia _|_ bronc | smoke, lung, dysp, either, xray, tub)
# (tub _|_ bronc, smoke, lung)
# (tub _|_ smoke, lung | bronc)
# (tub _|_ bronc, lung | smoke)
# (tub _|_ bronc, smoke | lung)
# (tub _|_ xray | either)
# (tub _|_ bronc, smoke, lung | asia)
# (tub _|_ lung | bronc, smoke)
# (tub _|_ smoke | bronc, lung)
# (tub _|_ dysp, xray | bronc, either)
# (tub _|_ smoke, lung | bronc, asia)
# (tub _|_ bronc | smoke, lung)
# (tub _|_ bronc, dysp, xray | either, smoke)
# (tub _|_ bronc, lung | smoke, asia)
# (tub _|_ bronc | smoke, xray)
# (tub _|_ bronc, dysp, smoke, xray | either, lung)
# (tub _|_ bronc, smoke | asia, lung)
# (tub _|_ bronc, smoke | xray, lung)
# (tub _|_ xray | dysp, either)
# (tub _|_ xray | either, asia)
# (tub _|_ dysp, xray | bronc, either, smoke)
# (tub _|_ lung | bronc, smoke, asia)
# (tub _|_ dysp, smoke, xray | bronc, either, lung)
# (tub _|_ smoke | bronc, dysp, lung)
# (tub _|_ smoke | bronc, asia, lung)
# (tub _|_ smoke | bronc, xray, lung)
# (tub _|_ xray | bronc, either, dysp)
# (tub _|_ dysp, xray | bronc, either, asia)
# (tub _|_ dysp | bronc, either, xray)
# (tub _|_ bronc, dysp, xray | either, smoke, lung)
# (tub _|_ bronc | smoke, asia, lung)
# (tub _|_ bronc | smoke, xray, lung)
# (tub _|_ bronc, xray | dysp, either, smoke)
# (tub _|_ bronc, dysp, xray | either, smoke, asia)
# (tub _|_ bronc, dysp | either, smoke, xray)
# (tub _|_ bronc | smoke, asia, xray)
# (tub _|_ bronc, smoke, xray | dysp, either, lung)
# (tub _|_ bronc, dysp, smoke, xray | either, asia, lung)
# (tub _|_ bronc, dysp, smoke | either, xray, lung)
# (tub _|_ bronc, smoke | asia, xray, lung)
# (tub _|_ xray | dysp, either, asia)
# (tub _|_ dysp, xray | bronc, either, smoke, lung)
# (tub _|_ xray | bronc, either, smoke, dysp)
# (tub _|_ dysp, xray | bronc, either, smoke, asia)
# (tub _|_ dysp | bronc, either, smoke, xray)
# (tub _|_ smoke, xray | bronc, either, dysp, lung)
# (tub _|_ dysp, smoke, xray | bronc, either, asia, lung)
# (tub _|_ dysp, smoke | bronc, either, xray, lung)
# (tub _|_ smoke | bronc, dysp, asia, lung)
# (tub _|_ smoke | bronc, dysp, xray, lung)
# (tub _|_ smoke | bronc, asia, xray, lung)
# (tub _|_ xray | bronc, either, dysp, asia)
# (tub _|_ dysp | bronc, either, asia, xray)
# (tub _|_ bronc, xray | dysp, either, smoke, lung)
# (tub _|_ bronc, dysp, xray | either, smoke, asia, lung)
# (tub _|_ bronc, dysp | either, smoke, xray, lung)
# (tub _|_ bronc | smoke, asia, xray, lung)
# (tub _|_ bronc, xray | dysp, either, smoke, asia)
# (tub _|_ bronc | dysp, either, smoke, xray)
# (tub _|_ bronc, dysp | either, smoke, asia, xray)
# (tub _|_ bronc, smoke, xray | dysp, either, asia, lung)
# (tub _|_ bronc, smoke | dysp, either, xray, lung)
# (tub _|_ bronc, dysp, smoke | either, asia, xray, lung)
# (tub _|_ xray | bronc, smoke, lung, either, dysp)
# (tub _|_ dysp, xray | bronc, smoke, lung, either, asia)
# (tub _|_ dysp | bronc, smoke, lung, either, xray)
# (tub _|_ xray | bronc, smoke, either, dysp, asia)
# (tub _|_ dysp | bronc, smoke, either, asia, xray)
# (tub _|_ smoke, xray | bronc, lung, either, dysp, asia)
# (tub _|_ smoke | bronc, lung, either, dysp, xray)
# (tub _|_ dysp, smoke | bronc, lung, either, asia, xray)
# (tub _|_ smoke | bronc, lung, dysp, asia, xray)
# (tub _|_ bronc, xray | smoke, lung, dysp, either, asia)
# (tub _|_ bronc | smoke, lung, dysp, either, xray)
# (tub _|_ bronc, dysp | smoke, lung, either, asia, xray)
# (tub _|_ bronc | smoke, dysp, either, asia, xray)
# (tub _|_ bronc, smoke | lung, dysp, either, asia, xray)
# (tub _|_ xray | bronc, smoke, lung, either, dysp, asia)
# (tub _|_ dysp | bronc, smoke, lung, either, asia, xray)
# (tub _|_ smoke | bronc, lung, either, dysp, asia, xray)
# (tub _|_ bronc | smoke, lung, dysp, either, asia, xray)
# (smoke _|_ asia, tub)
# (smoke _|_ asia, tub | bronc)
# (smoke _|_ either, asia, xray, tub | lung)
# (smoke _|_ xray | either)
# (smoke _|_ tub | asia)
# (smoke _|_ asia | tub)
# (smoke _|_ dysp, either, asia, xray, tub | bronc, lung)
# (smoke _|_ dysp, xray | bronc, either)
# (smoke _|_ tub | bronc, asia)
# (smoke _|_ asia | bronc, tub)
# (smoke _|_ asia, xray, tub | either, lung)
# (smoke _|_ either, xray, tub | asia, lung)
# (smoke _|_ either, asia, tub | xray, lung)
# (smoke _|_ either, asia, xray | lung, tub)
# (smoke _|_ xray | dysp, either)
# (smoke _|_ xray | either, asia)
# (smoke _|_ asia, xray | either, tub)
# (smoke _|_ asia | dysp, tub)
# (smoke _|_ asia | xray, tub)
# (smoke _|_ dysp, asia, xray, tub | bronc, either, lung)
# (smoke _|_ either, asia, xray, tub | bronc, dysp, lung)
# (smoke _|_ dysp, xray, tub, either | bronc, asia, lung)
# (smoke _|_ dysp, asia, tub, either | bronc, xray, lung)
# (smoke _|_ dysp, asia, xray, either | bronc, lung, tub)
# (smoke _|_ xray | bronc, either, dysp)
# (smoke _|_ dysp, xray | bronc, either, asia)
# (smoke _|_ dysp | bronc, either, xray)
# (smoke _|_ dysp, asia, xray | bronc, either, tub)
# (smoke _|_ asia | bronc, dysp, tub)
# (smoke _|_ asia | bronc, xray, tub)
# (smoke _|_ asia, xray, tub | dysp, either, lung)
# (smoke _|_ xray, tub | either, asia, lung)
# (smoke _|_ asia, tub | either, xray, lung)
# (smoke _|_ asia, xray | either, lung, tub)
# (smoke _|_ asia | dysp, lung, tub)
# (smoke _|_ either, tub | asia, xray, lung)
# (smoke _|_ either, xray | asia, lung, tub)
# (smoke _|_ either, asia | xray, lung, tub)
# (smoke _|_ xray | dysp, either, asia)
# (smoke _|_ asia, xray | dysp, either, tub)
# (smoke _|_ xray | either, asia, tub)
# (smoke _|_ asia | either, xray, tub)
# (smoke _|_ asia | dysp, xray, tub)
# (smoke _|_ asia, xray, tub | bronc, either, dysp, lung)
# (smoke _|_ dysp, xray, tub | bronc, either, asia, lung)
# (smoke _|_ dysp, asia, tub | bronc, either, xray, lung)
# (smoke _|_ dysp, asia, xray | bronc, either, lung, tub)
# (smoke _|_ either, xray, tub | bronc, dysp, asia, lung)
# (smoke _|_ either, asia, tub | bronc, dysp, xray, lung)
# (smoke _|_ either, asia, xray | bronc, dysp, lung, tub)
# (smoke _|_ dysp, tub, either | bronc, asia, xray, lung)
# (smoke _|_ dysp, xray, either | bronc, asia, lung, tub)
# (smoke _|_ dysp, asia, either | bronc, xray, lung, tub)
# (smoke _|_ xray | bronc, either, dysp, asia)
# (smoke _|_ asia, xray | bronc, either, dysp, tub)
# (smoke _|_ dysp | bronc, either, asia, xray)
# (smoke _|_ dysp, xray | bronc, either, asia, tub)
# (smoke _|_ dysp, asia | bronc, either, xray, tub)
# (smoke _|_ asia | bronc, dysp, xray, tub)
# (smoke _|_ xray, tub | dysp, either, asia, lung)
# (smoke _|_ asia, tub | dysp, either, xray, lung)
# (smoke _|_ asia, xray | dysp, either, lung, tub)
# (smoke _|_ tub | either, asia, xray, lung)
# (smoke _|_ xray | either, asia, lung, tub)
# (smoke _|_ asia | either, xray, lung, tub)
# (smoke _|_ asia | dysp, xray, lung, tub)
# (smoke _|_ either | asia, xray, lung, tub)
# (smoke _|_ xray | dysp, either, asia, tub)
# (smoke _|_ asia | dysp, either, xray, tub)
# (smoke _|_ xray, tub | bronc, lung, either, dysp, asia)
# (smoke _|_ asia, tub | bronc, lung, either, dysp, xray)
# (smoke _|_ asia, xray | bronc, lung, either, dysp, tub)
# (smoke _|_ dysp, tub | bronc, lung, either, asia, xray)
# (smoke _|_ dysp, xray | bronc, lung, either, asia, tub)
# (smoke _|_ dysp, asia | bronc, lung, either, xray, tub)
# (smoke _|_ either, tub | bronc, lung, dysp, asia, xray)
# (smoke _|_ either, xray | bronc, lung, dysp, asia, tub)
# (smoke _|_ either, asia | bronc, lung, dysp, xray, tub)
# (smoke _|_ dysp, either | bronc, lung, asia, xray, tub)
# (smoke _|_ xray | bronc, either, dysp, asia, tub)
# (smoke _|_ asia | bronc, either, dysp, xray, tub)
# (smoke _|_ dysp | bronc, either, asia, xray, tub)
# (smoke _|_ tub | lung, dysp, either, asia, xray)
# (smoke _|_ xray | lung, dysp, either, asia, tub)
# (smoke _|_ asia | lung, dysp, either, xray, tub)
# (smoke _|_ tub | bronc, lung, either, dysp, asia, xray)
# (smoke _|_ xray | bronc, lung, either, dysp, asia, tub)
# (smoke _|_ asia | bronc, lung, either, dysp, xray, tub)
# (smoke _|_ dysp | bronc, lung, either, asia, xray, tub)
# (smoke _|_ either | bronc, lung, dysp, asia, xray, tub)
# (lung _|_ asia, tub)
# (lung _|_ asia, tub | bronc)
# (lung _|_ bronc, asia, tub | smoke)
# (lung _|_ xray | either)
# (lung _|_ tub | asia)
# (lung _|_ asia | tub)
# (lung _|_ asia, tub | bronc, smoke)
# (lung _|_ dysp, xray | bronc, either)
# (lung _|_ tub | bronc, asia)
# (lung _|_ asia | bronc, tub)
# (lung _|_ bronc, dysp, xray | either, smoke)
# (lung _|_ bronc, tub | smoke, asia)
# (lung _|_ bronc | smoke, xray)
# (lung _|_ bronc, asia | smoke, tub)
# (lung _|_ xray | dysp, either)
# (lung _|_ xray | either, asia)
# (lung _|_ asia, xray | either, tub)
# (lung _|_ asia | dysp, tub)
# (lung _|_ asia | xray, tub)
# (lung _|_ dysp, xray | bronc, either, smoke)
# (lung _|_ tub | bronc, smoke, asia)
# (lung _|_ asia | bronc, smoke, tub)
# (lung _|_ xray | bronc, either, dysp)
# (lung _|_ dysp, xray | bronc, either, asia)
# (lung _|_ dysp | bronc, either, xray)
# (lung _|_ dysp, asia, xray | bronc, either, tub)
# (lung _|_ asia | bronc, dysp, tub)
# (lung _|_ asia | bronc, xray, tub)
# (lung _|_ bronc, xray | dysp, either, smoke)
# (lung _|_ bronc, dysp, xray | either, smoke, asia)
# (lung _|_ bronc, dysp | either, smoke, xray)
# (lung _|_ bronc, dysp, asia, xray | either, smoke, tub)
# (lung _|_ asia | dysp, smoke, tub)
# (lung _|_ bronc | smoke, asia, xray)
# (lung _|_ bronc | smoke, asia, tub)
# (lung _|_ bronc, asia | smoke, xray, tub)
# (lung _|_ xray | dysp, either, asia)
# (lung _|_ asia, xray | dysp, either, tub)
# (lung _|_ xray | either, asia, tub)
# (lung _|_ asia | either, xray, tub)
# (lung _|_ asia | dysp, xray, tub)
# (lung _|_ xray | bronc, either, smoke, dysp)
# (lung _|_ dysp, xray | bronc, either, smoke, asia)
# (lung _|_ dysp | bronc, either, smoke, xray)
# (lung _|_ dysp, asia, xray | bronc, either, smoke, tub)
# (lung _|_ asia | bronc, dysp, smoke, tub)
# (lung _|_ asia | bronc, smoke, xray, tub)
# (lung _|_ xray | bronc, either, dysp, asia)
# (lung _|_ asia, xray | bronc, either, dysp, tub)
# (lung _|_ dysp | bronc, either, asia, xray)
# (lung _|_ dysp, xray | bronc, either, asia, tub)
# (lung _|_ dysp, asia | bronc, either, xray, tub)
# (lung _|_ asia | bronc, dysp, xray, tub)
# (lung _|_ bronc, xray | dysp, either, smoke, asia)
# (lung _|_ bronc | dysp, either, smoke, xray)
# (lung _|_ bronc, asia, xray | dysp, either, smoke, tub)
# (lung _|_ bronc, dysp | either, smoke, asia, xray)
# (lung _|_ bronc, dysp, xray | either, smoke, asia, tub)
# (lung _|_ bronc, dysp, asia | either, smoke, xray, tub)
# (lung _|_ asia | dysp, smoke, xray, tub)
# (lung _|_ bronc | smoke, asia, xray, tub)
# (lung _|_ xray | dysp, either, asia, tub)
# (lung _|_ asia | dysp, either, xray, tub)
# (lung _|_ xray | bronc, smoke, either, dysp, asia)
# (lung _|_ asia, xray | bronc, smoke, either, dysp, tub)
# (lung _|_ dysp | bronc, smoke, either, asia, xray)
# (lung _|_ dysp, xray | bronc, smoke, either, asia, tub)
# (lung _|_ dysp, asia | bronc, smoke, either, xray, tub)
# (lung _|_ asia | bronc, smoke, dysp, xray, tub)
# (lung _|_ xray | bronc, either, dysp, asia, tub)
# (lung _|_ asia | bronc, either, dysp, xray, tub)
# (lung _|_ dysp | bronc, either, asia, xray, tub)
# (lung _|_ bronc | smoke, dysp, either, asia, xray)
# (lung _|_ bronc, xray | smoke, dysp, either, asia, tub)
# (lung _|_ bronc, asia | smoke, dysp, either, xray, tub)
# (lung _|_ bronc, dysp | smoke, either, asia, xray, tub)
# (lung _|_ xray | bronc, smoke, either, dysp, asia, tub)
# (lung _|_ asia | bronc, smoke, either, dysp, xray, tub)
# (lung _|_ dysp | bronc, smoke, either, asia, xray, tub)
# (lung _|_ bronc | smoke, dysp, either, asia, xray, tub)
# (bronc _|_ asia, tub)
# (bronc _|_ either, asia, xray, lung, tub | smoke)
# (bronc _|_ either, asia, xray, tub | lung)
# (bronc _|_ xray | either)
# (bronc _|_ tub | asia)
# (bronc _|_ asia | tub)
# (bronc _|_ either, asia, xray, tub | smoke, lung)
# (bronc _|_ asia, xray, lung, tub | either, smoke)
# (bronc _|_ either, xray, lung, tub | smoke, asia)
# (bronc _|_ either, asia, lung, tub | smoke, xray)
# (bronc _|_ either, asia, xray, lung | smoke, tub)
# (bronc _|_ asia, xray, tub | either, lung)
# (bronc _|_ either, xray, tub | asia, lung)
# (bronc _|_ either, asia, tub | xray, lung)
# (bronc _|_ either, asia, xray | lung, tub)
# (bronc _|_ xray | dysp, either)
# (bronc _|_ xray | either, asia)
# (bronc _|_ asia, xray | either, tub)
# (bronc _|_ asia | dysp, tub)
# (bronc _|_ asia | xray, tub)
# (bronc _|_ asia, xray, tub | either, smoke, lung)
# (bronc _|_ either, xray, tub | smoke, asia, lung)
# (bronc _|_ either, asia, tub | smoke, xray, lung)
# (bronc _|_ either, asia, xray | smoke, lung, tub)
# (bronc _|_ asia, xray, lung, tub | dysp, either, smoke)
# (bronc _|_ xray, lung, tub | either, smoke, asia)
# (bronc _|_ asia, lung, tub | either, smoke, xray)
# (bronc _|_ asia, xray, lung | either, smoke, tub)
# (bronc _|_ asia | dysp, smoke, tub)
# (bronc _|_ either, lung, tub | smoke, asia, xray)
# (bronc _|_ either, xray, lung | smoke, asia, tub)
# (bronc _|_ either, asia, lung | smoke, xray, tub)
# (bronc _|_ asia, xray, tub | dysp, either, lung)
# (bronc _|_ xray, tub | either, asia, lung)
# (bronc _|_ asia, tub | either, xray, lung)
# (bronc _|_ asia, xray | either, lung, tub)
# (bronc _|_ asia | dysp, lung, tub)
# (bronc _|_ either, tub | asia, xray, lung)
# (bronc _|_ either, xray | asia, lung, tub)
# (bronc _|_ either, asia | xray, lung, tub)
# (bronc _|_ xray | dysp, either, asia)
# (bronc _|_ asia, xray | dysp, either, tub)
# (bronc _|_ xray | either, asia, tub)
# (bronc _|_ asia | either, xray, tub)
# (bronc _|_ asia | dysp, xray, tub)
# (bronc _|_ asia, xray, tub | dysp, either, smoke, lung)
# (bronc _|_ xray, tub | either, smoke, asia, lung)
# (bronc _|_ asia, tub | either, smoke, xray, lung)
# (bronc _|_ asia, xray | either, smoke, lung, tub)
# (bronc _|_ asia | dysp, smoke, lung, tub)
# (bronc _|_ either, tub | smoke, asia, xray, lung)
# (bronc _|_ either, xray | smoke, asia, lung, tub)
# (bronc _|_ either, asia | smoke, xray, lung, tub)
# (bronc _|_ xray, lung, tub | dysp, either, smoke, asia)
# (bronc _|_ asia, lung, tub | dysp, either, smoke, xray)
# (bronc _|_ asia, xray, lung | dysp, either, smoke, tub)
# (bronc _|_ lung, tub | either, smoke, asia, xray)
# (bronc _|_ xray, lung | either, smoke, asia, tub)
# (bronc _|_ asia, lung | either, smoke, xray, tub)
# (bronc _|_ asia | dysp, smoke, xray, tub)
# (bronc _|_ either, lung | smoke, asia, xray, tub)
# (bronc _|_ xray, tub | dysp, either, asia, lung)
# (bronc _|_ asia, tub | dysp, either, xray, lung)
# (bronc _|_ asia, xray | dysp, either, lung, tub)
# (bronc _|_ tub | either, asia, xray, lung)
# (bronc _|_ xray | either, asia, lung, tub)
# (bronc _|_ asia | either, xray, lung, tub)
# (bronc _|_ asia | dysp, xray, lung, tub)
# (bronc _|_ either | asia, xray, lung, tub)
# (bronc _|_ xray | dysp, either, asia, tub)
# (bronc _|_ asia | dysp, either, xray, tub)
# (bronc _|_ xray, tub | smoke, lung, dysp, either, asia)
# (bronc _|_ asia, tub | smoke, lung, dysp, either, xray)
# (bronc _|_ asia, xray | smoke, lung, dysp, either, tub)
# (bronc _|_ tub | smoke, lung, either, asia, xray)
# (bronc _|_ xray | smoke, lung, either, asia, tub)
# (bronc _|_ asia | smoke, lung, either, xray, tub)
# (bronc _|_ asia | smoke, lung, dysp, xray, tub)
# (bronc _|_ either | smoke, lung, asia, xray, tub)
# (bronc _|_ lung, tub | smoke, dysp, either, asia, xray)
# (bronc _|_ xray, lung | smoke, dysp, either, asia, tub)
# (bronc _|_ asia, lung | smoke, dysp, either, xray, tub)
# (bronc _|_ lung | smoke, either, asia, xray, tub)
# (bronc _|_ tub | lung, dysp, either, asia, xray)
# (bronc _|_ xray | lung, dysp, either, asia, tub)
# (bronc _|_ asia | lung, dysp, either, xray, tub)
# (bronc _|_ tub | smoke, lung, dysp, either, asia, xray)
# (bronc _|_ xray | smoke, lung, dysp, either, asia, tub)
# (bronc _|_ asia | smoke, lung, dysp, either, xray, tub)
# (bronc _|_ lung | smoke, dysp, either, asia, xray, tub)
# (either _|_ bronc | smoke)
# (either _|_ bronc, smoke | lung)
# (either _|_ asia | tub)
# (either _|_ smoke | bronc, lung)
# (either _|_ asia | bronc, tub)
# (either _|_ bronc | smoke, lung)
# (either _|_ bronc | smoke, asia)
# (either _|_ bronc | smoke, xray)
# (either _|_ bronc, asia | smoke, tub)
# (either _|_ bronc, smoke | asia, lung)
# (either _|_ bronc, smoke | xray, lung)
# (either _|_ bronc, smoke, asia | lung, tub)
# (either _|_ asia | dysp, tub)
# (either _|_ asia | xray, tub)
# (either _|_ asia | bronc, smoke, tub)
# (either _|_ smoke | bronc, dysp, lung)
# (either _|_ smoke | bronc, asia, lung)
# (either _|_ smoke | bronc, xray, lung)
# (either _|_ smoke, asia | bronc, lung, tub)
# (either _|_ asia | bronc, dysp, tub)
# (either _|_ asia | bronc, xray, tub)
# (either _|_ bronc | smoke, asia, lung)
# (either _|_ bronc | smoke, xray, lung)
# (either _|_ bronc, asia | smoke, lung, tub)
# (either _|_ asia | dysp, smoke, tub)
# (either _|_ bronc | smoke, asia, xray)
# (either _|_ bronc | smoke, asia, tub)
# (either _|_ bronc, asia | smoke, xray, tub)
# (either _|_ asia | dysp, lung, tub)
# (either _|_ bronc, smoke | asia, xray, lung)
# (either _|_ bronc, smoke | asia, lung, tub)
# (either _|_ bronc, smoke, asia | xray, lung, tub)
# (either _|_ asia | dysp, xray, tub)
# (either _|_ asia | bronc, smoke, lung, tub)
# (either _|_ asia | bronc, dysp, smoke, tub)
# (either _|_ asia | bronc, smoke, xray, tub)
# (either _|_ smoke | bronc, dysp, asia, lung)
# (either _|_ smoke | bronc, dysp, xray, lung)
# (either _|_ smoke, asia | bronc, dysp, lung, tub)
# (either _|_ smoke | bronc, asia, xray, lung)
# (either _|_ smoke | bronc, asia, lung, tub)
# (either _|_ smoke, asia | bronc, xray, lung, tub)
# (either _|_ asia | bronc, dysp, xray, tub)
# (either _|_ asia | dysp, smoke, lung, tub)
# (either _|_ bronc | smoke, asia, xray, lung)
# (either _|_ bronc | smoke, asia, lung, tub)
# (either _|_ bronc, asia | smoke, xray, lung, tub)
# (either _|_ asia | dysp, smoke, xray, tub)
# (either _|_ bronc | smoke, asia, xray, tub)
# (either _|_ asia | dysp, xray, lung, tub)
# (either _|_ bronc, smoke | asia, xray, lung, tub)
# (either _|_ asia | bronc, smoke, lung, dysp, tub)
# (either _|_ asia | bronc, smoke, lung, xray, tub)
# (either _|_ asia | bronc, smoke, dysp, xray, tub)
# (either _|_ smoke | bronc, lung, dysp, asia, xray)
# (either _|_ smoke | bronc, lung, dysp, asia, tub)
# (either _|_ smoke, asia | bronc, lung, dysp, xray, tub)
# (either _|_ smoke | bronc, lung, asia, xray, tub)
# (either _|_ asia | smoke, lung, dysp, xray, tub)
# (either _|_ bronc | smoke, lung, asia, xray, tub)
# (either _|_ asia | bronc, smoke, lung, dysp, xray, tub)
# (either _|_ smoke | bronc, lung, dysp, asia, xray, tub)
# (xray _|_ bronc | smoke)
# (xray _|_ bronc, smoke | lung)
# (xray _|_ bronc, dysp, smoke, asia, lung, tub | either)
# (xray _|_ asia | tub)
# (xray _|_ smoke | bronc, lung)
# (xray _|_ dysp, smoke, asia, lung, tub | bronc, either)
# (xray _|_ asia | bronc, tub)
# (xray _|_ bronc | smoke, lung)
# (xray _|_ bronc, dysp, asia, lung, tub | either, smoke)
# (xray _|_ bronc | smoke, asia)
# (xray _|_ bronc, asia | smoke, tub)
# (xray _|_ bronc, dysp, smoke, asia, tub | either, lung)
# (xray _|_ bronc, smoke | asia, lung)
# (xray _|_ bronc, smoke, asia | lung, tub)
# (xray _|_ bronc, smoke, asia, lung, tub | dysp, either)
# (xray _|_ bronc, dysp, smoke, lung, tub | either, asia)
# (xray _|_ bronc, dysp, smoke, asia, lung | either, tub)
# (xray _|_ asia | dysp, tub)
# (xray _|_ dysp, asia, lung, tub | bronc, either, smoke)
# (xray _|_ asia | bronc, smoke, tub)
# (xray _|_ dysp, smoke, asia, tub | bronc, either, lung)
# (xray _|_ smoke | bronc, dysp, lung)
# (xray _|_ smoke | bronc, asia, lung)
# (xray _|_ smoke, asia | bronc, lung, tub)
# (xray _|_ smoke, asia, lung, tub | bronc, either, dysp)
# (xray _|_ dysp, smoke, lung, tub | bronc, either, asia)
# (xray _|_ dysp, smoke, asia, lung | bronc, either, tub)
# (xray _|_ asia | bronc, dysp, tub)
# (xray _|_ bronc, dysp, asia, tub | either, smoke, lung)
# (xray _|_ bronc | smoke, asia, lung)
# (xray _|_ bronc, asia | smoke, lung, tub)
# (xray _|_ bronc, asia, lung, tub | dysp, either, smoke)
# (xray _|_ bronc, dysp, lung, tub | either, smoke, asia)
# (xray _|_ bronc, dysp, asia, lung | either, smoke, tub)
# (xray _|_ asia | dysp, smoke, tub)
# (xray _|_ bronc | smoke, asia, tub)
# (xray _|_ bronc, smoke, asia, tub | dysp, either, lung)
# (xray _|_ bronc, dysp, smoke, tub | either, asia, lung)
# (xray _|_ bronc, dysp, smoke, asia | either, lung, tub)
# (xray _|_ asia | dysp, lung, tub)
# (xray _|_ bronc, smoke | asia, lung, tub)
# (xray _|_ bronc, smoke, lung, tub | dysp, either, asia)
# (xray _|_ bronc, smoke, asia, lung | dysp, either, tub)
# (xray _|_ bronc, dysp, smoke, lung | either, asia, tub)
# (xray _|_ dysp, asia, tub | bronc, either, smoke, lung)
# (xray _|_ asia | bronc, smoke, lung, tub)
# (xray _|_ asia, lung, tub | bronc, either, smoke, dysp)
# (xray _|_ dysp, lung, tub | bronc, either, smoke, asia)
# (xray _|_ dysp, asia, lung | bronc, either, smoke, tub)
# (xray _|_ asia | bronc, dysp, smoke, tub)
# (xray _|_ smoke, asia, tub | bronc, either, dysp, lung)
# (xray _|_ dysp, smoke, tub | bronc, either, asia, lung)
# (xray _|_ dysp, smoke, asia | bronc, either, lung, tub)
# (xray _|_ smoke | bronc, dysp, asia, lung)
# (xray _|_ smoke, asia | bronc, dysp, lung, tub)
# (xray _|_ smoke | bronc, asia, lung, tub)
# (xray _|_ smoke, lung, tub | bronc, either, dysp, asia)
# (xray _|_ smoke, asia, lung | bronc, either, dysp, tub)
# (xray _|_ dysp, smoke, lung | bronc, either, asia, tub)
# (xray _|_ bronc, asia, tub | dysp, either, smoke, lung)
# (xray _|_ bronc, dysp, tub | either, smoke, asia, lung)
# (xray _|_ bronc, dysp, asia | either, smoke, lung, tub)
# (xray _|_ asia | dysp, smoke, lung, tub)
# (xray _|_ bronc | smoke, asia, lung, tub)
# (xray _|_ bronc, lung, tub | dysp, either, smoke, asia)
# (xray _|_ bronc, asia, lung | dysp, either, smoke, tub)
# (xray _|_ bronc, dysp, lung | either, smoke, asia, tub)
# (xray _|_ bronc, smoke, tub | dysp, either, asia, lung)
# (xray _|_ bronc, smoke, asia | dysp, either, lung, tub)
# (xray _|_ bronc, dysp, smoke | either, asia, lung, tub)
# (xray _|_ bronc, smoke, lung | dysp, either, asia, tub)
# (xray _|_ asia, tub | bronc, smoke, lung, either, dysp)
# (xray _|_ dysp, tub | bronc, smoke, lung, either, asia)
# (xray _|_ dysp, asia | bronc, smoke, lung, either, tub)
# (xray _|_ asia | bronc, smoke, lung, dysp, tub)
# (xray _|_ lung, tub | bronc, smoke, either, dysp, asia)
# (xray _|_ asia, lung | bronc, smoke, either, dysp, tub)
# (xray _|_ dysp, lung | bronc, smoke, either, asia, tub)
# (xray _|_ smoke, tub | bronc, lung, either, dysp, asia)
# (xray _|_ smoke, asia | bronc, lung, either, dysp, tub)
# (xray _|_ dysp, smoke | bronc, lung, either, asia, tub)
# (xray _|_ smoke | bronc, lung, dysp, asia, tub)
# (xray _|_ smoke, lung | bronc, either, dysp, asia, tub)
# (xray _|_ bronc, tub | smoke, lung, dysp, either, asia)
# (xray _|_ bronc, asia | smoke, lung, dysp, either, tub)
# (xray _|_ bronc, dysp | smoke, lung, either, asia, tub)
# (xray _|_ bronc, lung | smoke, dysp, either, asia, tub)
# (xray _|_ bronc, smoke | lung, dysp, either, asia, tub)
# (xray _|_ tub | bronc, smoke, lung, either, dysp, asia)
# (xray _|_ asia | bronc, smoke, lung, either, dysp, tub)
# (xray _|_ dysp | bronc, smoke, lung, either, asia, tub)
# (xray _|_ lung | bronc, smoke, either, dysp, asia, tub)
# (xray _|_ smoke | bronc, lung, either, dysp, asia, tub)
# (xray _|_ bronc | smoke, lung, dysp, either, asia, tub)
# (dysp _|_ xray | either)
# (dysp _|_ asia | tub)
# (dysp _|_ smoke | bronc, lung)
# (dysp _|_ smoke, asia, xray, lung, tub | bronc, either)
# (dysp _|_ asia | bronc, tub)
# (dysp _|_ asia, xray, lung, tub | either, smoke)
# (dysp _|_ asia | smoke, tub)
# (dysp _|_ asia, xray, tub | either, lung)
# (dysp _|_ asia | lung, tub)
# (dysp _|_ xray | either, asia)
# (dysp _|_ asia, xray | either, tub)
# (dysp _|_ asia | xray, tub)
# (dysp _|_ asia, xray, lung, tub | bronc, either, smoke)
# (dysp _|_ asia | bronc, smoke, tub)
# (dysp _|_ smoke, asia, xray, tub | bronc, either, lung)
# (dysp _|_ smoke | bronc, asia, lung)
# (dysp _|_ smoke | bronc, xray, lung)
# (dysp _|_ smoke, asia | bronc, lung, tub)
# (dysp _|_ smoke, xray, lung, tub | bronc, either, asia)
# (dysp _|_ smoke, asia, lung, tub | bronc, either, xray)
# (dysp _|_ smoke, asia, xray, lung | bronc, either, tub)
# (dysp _|_ asia | bronc, xray, tub)
# (dysp _|_ asia, xray, tub | either, smoke, lung)
# (dysp _|_ asia | smoke, lung, tub)
# (dysp _|_ xray, lung, tub | either, smoke, asia)
# (dysp _|_ asia, lung, tub | either, smoke, xray)
# (dysp _|_ asia, xray, lung | either, smoke, tub)
# (dysp _|_ asia | smoke, xray, tub)
# (dysp _|_ xray, tub | either, asia, lung)
# (dysp _|_ asia, tub | either, xray, lung)
# (dysp _|_ asia, xray | either, lung, tub)
# (dysp _|_ asia | xray, lung, tub)
# (dysp _|_ xray | either, asia, tub)
# (dysp _|_ asia | either, xray, tub)
# (dysp _|_ asia, xray, tub | bronc, either, smoke, lung)
# (dysp _|_ asia | bronc, smoke, lung, tub)
# (dysp _|_ xray, lung, tub | bronc, either, smoke, asia)
# (dysp _|_ asia, lung, tub | bronc, either, smoke, xray)
# (dysp _|_ asia, xray, lung | bronc, either, smoke, tub)
# (dysp _|_ asia | bronc, smoke, xray, tub)
# (dysp _|_ smoke, xray, tub | bronc, either, asia, lung)
# (dysp _|_ smoke, asia, tub | bronc, either, xray, lung)
# (dysp _|_ smoke, asia, xray | bronc, either, lung, tub)
# (dysp _|_ smoke | bronc, asia, xray, lung)
# (dysp _|_ smoke | bronc, asia, lung, tub)
# (dysp _|_ smoke, asia | bronc, xray, lung, tub)
# (dysp _|_ smoke, lung, tub | bronc, either, asia, xray)
# (dysp _|_ smoke, xray, lung | bronc, either, asia, tub)
# (dysp _|_ smoke, asia, lung | bronc, either, xray, tub)
# (dysp _|_ xray, tub | either, smoke, asia, lung)
# (dysp _|_ asia, tub | either, smoke, xray, lung)
# (dysp _|_ asia, xray | either, smoke, lung, tub)
# (dysp _|_ asia | smoke, xray, lung, tub)
# (dysp _|_ lung, tub | either, smoke, asia, xray)
# (dysp _|_ xray, lung | either, smoke, asia, tub)
# (dysp _|_ asia, lung | either, smoke, xray, tub)
# (dysp _|_ tub | either, asia, xray, lung)
# (dysp _|_ xray | either, asia, lung, tub)
# (dysp _|_ asia | either, xray, lung, tub)
# (dysp _|_ xray, tub | bronc, smoke, lung, either, asia)
# (dysp _|_ asia, tub | bronc, smoke, lung, either, xray)
# (dysp _|_ asia, xray | bronc, smoke, lung, either, tub)
# (dysp _|_ asia | bronc, smoke, lung, xray, tub)
# (dysp _|_ lung, tub | bronc, smoke, either, asia, xray)
# (dysp _|_ xray, lung | bronc, smoke, either, asia, tub)
# (dysp _|_ asia, lung | bronc, smoke, either, xray, tub)
# (dysp _|_ smoke, tub | bronc, lung, either, asia, xray)
# (dysp _|_ smoke, xray | bronc, lung, either, asia, tub)
# (dysp _|_ smoke, asia | bronc, lung, either, xray, tub)
# (dysp _|_ smoke | bronc, lung, asia, xray, tub)
# (dysp _|_ smoke, lung | bronc, either, asia, xray, tub)
# (dysp _|_ tub | smoke, lung, either, asia, xray)
# (dysp _|_ xray | smoke, lung, either, asia, tub)
# (dysp _|_ asia | smoke, lung, either, xray, tub)
# (dysp _|_ lung | smoke, either, asia, xray, tub)
# (dysp _|_ tub | bronc, smoke, lung, either, asia, xray)
# (dysp _|_ xray | bronc, smoke, lung, either, asia, tub)
# (dysp _|_ asia | bronc, smoke, lung, either, xray, tub)
# (dysp _|_ lung | bronc, smoke, either, asia, xray, tub)
# (dysp _|_ smoke | bronc, lung, either, asia, xray, tub)

# %% [markdown]
# ## 2. Make Inferences

# %% [markdown]
# **Q1.** What is the probability of a person having bronchitis given that he/she doesn't smoke?

# %% [markdown]
# **Q2.** What is the probability that the person is a smoker given that their x-ray result is positive

# %% [markdown]
# **Q3.** Consider the following two probabilities:
#
# 1. The probability that a person doesn't have dyspnea given that he has bronchitis.
# 2. The probability that a person doesn't have dyspnea given that he has bronchitis and doesn't have lung cancer.
#
# By what percent does the probability increase or decrease from situation 1 to situation 2?
